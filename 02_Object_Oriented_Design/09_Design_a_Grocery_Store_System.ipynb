# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon { font-size: 22px !important; line-height: 1.8 !important; }
# .jp-RenderedHTMLCommon h2 { font-size: 1.7em !important; border-left: 5px solid #bc6c25 !important; padding: 10px 0 10px 18px !important; margin-top: 40px !important; background: linear-gradient(90deg, rgba(188,108,37,0.08) 0%, transparent 60%) !important; border-radius: 4px !important; }
# .jp-RenderedHTMLCommon h3 { font-size: 1.35em !important; border-bottom: 2px solid rgba(188,108,37,0.3) !important; padding-bottom: 8px !important; margin-top: 30px !important; color: #bc6c25 !important; }
# .jp-RenderedHTMLCommon h4 { font-size: 1.15em !important; font-style: italic !important; color: #bc6c25 !important; margin-top: 22px !important; }
# </style>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #283618 0%, #606c38 50%, #bc6c25 100%); padding: 40px 45px; border-radius: 16px; margin-bottom: 30px; border: 1px solid rgba(42,157,143,0.15); max-width: 95%; overflow: hidden; box-sizing: border-box;">
#   <div style="font-size: 15px; font-weight: 600; letter-spacing: 3px; text-transform: uppercase; color: #bc6c25; margin-bottom: 8px;">Chapter 09</div>
#   <div style="font-size: 36px; font-weight: 800; color: #ffffff; margin-bottom: 16px; line-height: 1.2;">Design a Grocery Store System</div>
#   <div style="width: 60px; height: 4px; background: linear-gradient(90deg, #bc6c25, rgba(42,157,143,0.5)); border-radius: 2px; margin-bottom: 18px;"></div>
#   <div style="font-size: 17px; color: #b0bec5; line-height: 1.6;">Object-Oriented Design Interview Question</div>
#   <div style="margin-top: 20px; font-size: 13px; color: #546e7a;">Source: ByteByteGo — Object-Oriented Design Interview</div>
# </div>

# %% [markdown]
# In this chapter, we will explore the design of a grocery store system. This system is tailored for grocery store workers to streamline operations like managing the item catalog, configuring pricing, and applying discounts.

# %% [markdown]
# ![Figure 1: Grocery Store System](assets/image-9-1-OKDF2ZPY.svg)

# %% [markdown]
# <div style="border-left: 5px solid #bc6c25; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(188,108,37,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Requirements Gathering</span>
# </div>

# %% [markdown]
# > “Imagine you’re at a grocery store, filling your cart with fresh produce, snacks, and household essentials. At the checkout, the cashier scans each item, and the system instantly tracks the order, applies any discounts, and displays the final total. Behind the scenes, the system is seamlessly managing the item catalog, updating inventory as stock arrives or sells, and ensuring every transaction is smooth and accurate. Now, let’s design a grocery store system that does all this.”

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Requirements clarification</span>
# </div>

# %% [markdown]
# <div style="border: 1px solid rgba(188,108,37,0.3); border-radius: 8px; margin: 28px 0; overflow: hidden; font-family: system-ui, -apple-system, sans-serif;">
#   <div style="background: rgba(188,108,37,0.08); padding: 10px 20px; border-bottom: 1px solid rgba(188,108,37,0.3); display: flex; align-items: center; gap: 8px;">
#     <span style="font-size: 1.1em;">&#128483;</span>
#     <span style="font-size: 0.85em; font-weight: 700; color: #bc6c25; text-transform: uppercase; letter-spacing: 1.5px;">Interview Transcript</span>
#   </div>
#   <div style="padding: 24px 20px 24px 28px; position: relative;">
#     <div style="position: absolute; left: 38px; top: 24px; bottom: 24px; width: 2px; background: rgba(188,108,37,0.3);"></div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #bc6c25; border: 3px solid transparent; box-shadow: 0 0 0 2px #bc6c25; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #bc6c25; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #bc6c25; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">What are the primary operations the grocery store system needs to support?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">The system should support store workers, including shipment handlers and cashiers, in managing the item catalog, tracking inventory, and processing customer checkouts with applicable discounts.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #bc6c25; border: 3px solid transparent; box-shadow: 0 0 0 2px #bc6c25; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #bc6c25; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #bc6c25; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">I’d like to confirm my understanding of the checkout process. The cashier scans or enters a code for each item, and the system keeps track of the order. It calculates the subtotal, applies any discounts, and updates the total. Once all items are entered, the cashier sees the final amount, accepts payment, and provides change if needed. A receipt is then generated. Does this sound correct?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, that’s an accurate understanding of the system.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #bc6c25; border: 3px solid transparent; box-shadow: 0 0 0 2px #bc6c25; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #bc6c25; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #bc6c25; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">How should the system handle inventory management?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">The system should track inventory for all items, increasing inventory when new stock arrives and automatically decreasing inventory during checkout for items sold.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #bc6c25; border: 3px solid transparent; box-shadow: 0 0 0 2px #bc6c25; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #bc6c25; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #bc6c25; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Should the system categorize items into different categories, such as food, beverages, etc.?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, that’s a good idea.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #bc6c25; border: 3px solid transparent; box-shadow: 0 0 0 2px #bc6c25; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #bc6c25; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #bc6c25; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">For discounts, can I assume the system should track discount campaigns, which can apply to specific items or categories? If multiple discounts apply to the same item, the system should automatically apply the highest discount.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">That sounds great.</div>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Requirements</span>
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">Catalog management</span>
# </div>

# %% [markdown]
# * Admins can add, update, and remove items from the catalog.
#
# * The catalog tracks item details, including name, category, price, and barcode.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">Inventory management</span>
# </div>

# %% [markdown]
# * Shipment handlers can update inventory when shipments arrive.
#
# * The system should automatically decrease inventory when items are sold.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">Checkout process</span>
# </div>

# %% [markdown]
# * Cashiers can scan barcodes or manually enter item codes to build an order.
#
# * Cashiers can view details of the active order, including items, discounts, and the subtotal.
#
# * The system calculates and applies relevant discounts automatically.
#
# * Cashiers can finalize an order, calculate the total, handle payments, and calculate change.
#
# * A detailed receipt is generated.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">Discount campaigns</span>
# </div>

# %% [markdown]
# * Admins can define discount campaigns for specific items or categories.
#
# * If multiple discounts apply to an item, the system selects the highest discount.

# %% [markdown]
# Non-functional requirements:

# %% [markdown]
# * Clear, user-friendly error messages for invalid barcodes or insufficient inventory.
#
# * Modular components (catalog, inventory, checkout, discounts) to allow updates without affecting the entire system.

# %% [markdown]
# <div style="border-left: 5px solid #bc6c25; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(188,108,37,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Identify Core Objects</span>
# </div>

# %% [markdown]
# * **Item**: Represents an individual product with name, barcode, category, and price.
#
# * **Catalog**: Central repository for all items, supporting add, update, and remove.
#
# * **Inventory**: Tracks stock levels for each item.
#
# * **Order**: Tracks the ongoing checkout process — items, discounts, subtotals, and totals.
#
# * **DiscountCampaign**: Defines promotional rules for applying discounts.

# %% [markdown]
# <div style="border-left: 5px solid #bc6c25; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(188,108,37,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Design Class Diagram</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Item</span>
# </div>

# %% [markdown]
# ![Figure 2: Item class](assets/image-9-2-I76WBLE6.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Catalog</span>
# </div>

# %% [markdown]
# ![Figure 3: Catalog class](assets/image-9-3-HNYW6M54.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Inventory</span>
# </div>

# %% [markdown]
# ![Figure 4: Inventory class](assets/image-9-4-E4RVAO3P.svg)

# %% [markdown]
# **Design choice**: Static product details (Catalog) are separated from dynamic stock levels (Inventory), adhering to the Single Responsibility Principle.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">DiscountCriteria</span>
# </div>

# %% [markdown]
# The DiscountCriteria interface encapsulates the logic to determine whether a discount applies to an item.

# %% [markdown]
# ![Figure 5: DiscountCriteria interface and concrete classes](assets/image-9-5-Y7KTXGCQ.svg)

# %% [markdown]
# * **CategoryBasedCriteria**: Checks if an item belongs to a specific category.
#
# * **ItemBasedCriteria**: Checks if a discount applies to a specific item by matching its unique identifier.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">DiscountCalculationStrategy</span>
# </div>

# %% [markdown]
# The DiscountCalculationStrategy interface uses the Strategy Pattern for flexible discount types.

# %% [markdown]
# ![Figure 6: DiscountCalculationStrategy interface](assets/image-9-6-YE2QJBHY.svg)

# %% [markdown]
# * **AmountBasedStrategy**: Applies a fixed discount amount.
#
# * **PercentageBasedStrategy**: Applies a percentage-based discount.

# %% [markdown]
# **Design choice**: This design is highly extensible — new strategies like tiered discounts can be added without modifying existing code (Open/Closed Principle).

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">DiscountCampaign</span>
# </div>

# %% [markdown]
# ![Figure 7: DiscountCampaign class](assets/image-9-7-SKQ2E4QT.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">OrderItem</span>
# </div>

# %% [markdown]
# ![Figure 8: OrderItem class](assets/image-9-8-RK66CMKD.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Order</span>
# </div>

# %% [markdown]
# ![Figure 9: Order class](assets/image-9-9-4B4ID6DV.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Receipt</span>
# </div>

# %% [markdown]
# ![Figure 10: Receipt class](assets/image-9-10-DVYMNR2X.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Checkout</span>
# </div>

# %% [markdown]
# ![Figure 11: Checkout class](assets/image-9-11-PL45OV3E.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">GroceryStoreSystem</span>
# </div>

# %% [markdown]
# ![Figure 12: GroceryStoreSystem class](assets/image-9-12-J35DG7KF.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Complete Class Diagram</span>
# </div>

# %% [markdown]
# ![Figure 13: Class Diagram of Grocery Store System](assets/image-9-13-7HDBZPTE.svg)

# %% [markdown]
# <div style="border-left: 5px solid #bc6c25; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(188,108,37,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Code - Grocery Store System</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Item</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Item {
#     private final String name;
#     private final String barcode;
#     private final String category;
#     private BigDecimal price;
#
#     public Item(String name, String barcode, String category, BigDecimal price) {
#         this.name = name;
#         this.barcode = barcode;
#         this.category = category;
#         this.price = price;
#     }
#     // getter and setter methods are omitted for brevity
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Catalog</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Catalog {
#     private final Map<String, Item> items = new HashMap<>();
#
#     public void updateItem(Item item) { items.put(item.getBarcode(), item); }
#     public void removeItem(String barcode) { items.remove(barcode); }
#     public Item getItem(String barcode) { return items.get(barcode); }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Inventory</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Inventory {
#     private final Map<String, Integer> stock = new HashMap<>();
#
#     public void addStock(String barcode, int count) {
#         stock.put(barcode, stock.getOrDefault(barcode, 0) + count);
#     }
#     public void reduceStock(String barcode, int count) {
#         stock.put(barcode, stock.getOrDefault(barcode, 0) - count);
#     }
#     public int getStock(String barcode) {
#         return stock.getOrDefault(barcode, 0);
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">DiscountCampaign</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class DiscountCampaign {
#     private final String discountId;
#     private final String name;
#     private final DiscountCriteria criteria;
#     private final DiscountCalculationStrategy calculationStrategy;
#
#     public DiscountCampaign(String discountId, String name,
#             DiscountCriteria criteria,
#             DiscountCalculationStrategy calculationStrategy) {
#         this.discountId = discountId;
#         this.name = name;
#         this.criteria = criteria;
#         this.calculationStrategy = calculationStrategy;
#     }
#
#     public boolean isApplicable(Item item) {
#         return criteria.isApplicable(item);
#     }
#
#     public BigDecimal calculateDiscount(OrderItem item) {
#         return calculationStrategy.calculateDiscountedPrice(item.calculatePrice());
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">OrderItem</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class OrderItem {
#     private final Item item;
#     private final int quantity;
#
#     public OrderItem(Item item, int quantity) {
#         this.item = item;
#         this.quantity = quantity;
#     }
#
#     public BigDecimal calculatePrice() {
#         return item.getPrice().multiply(BigDecimal.valueOf(quantity));
#     }
#
#     public BigDecimal calculatePriceWithDiscount(DiscountCampaign newDiscount) {
#         return newDiscount.calculateDiscount(this);
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Order</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Order {
#     private final String orderId;
#     private final List<OrderItem> items = new ArrayList<>();
#     private final Map<OrderItem, DiscountCampaign> appliedDiscounts = new HashMap<>();
#     private BigDecimal paymentAmount = BigDecimal.ZERO;
#
#     public Order() { this.orderId = String.valueOf(UUID.randomUUID()); }
#
#     public void addItem(OrderItem item) { items.add(item); }
#
#     public BigDecimal calculateSubtotal() {
#         return items.stream()
#                 .map(OrderItem::calculatePrice)
#                 .reduce(BigDecimal.ZERO, BigDecimal::add);
#     }
#
#     public BigDecimal calculateTotal() {
#         return items.stream()
#                 .map(item -> {
#                     DiscountCampaign discount = appliedDiscounts.get(item);
#                     return discount != null
#                             ? item.calculatePriceWithDiscount(discount)
#                             : item.calculatePrice();
#                 })
#                 .reduce(BigDecimal.ZERO, BigDecimal::add);
#     }
#
#     public void applyDiscount(OrderItem item, DiscountCampaign discount) {
#         appliedDiscounts.put(item, discount);
#     }
#
#     public BigDecimal calculateChange() {
#         return paymentAmount.subtract(calculateTotal());
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Checkout</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Checkout {
#     private Order currentOrder;
#     private final List<DiscountCampaign> activeDiscounts;
#
#     public Checkout(List<DiscountCampaign> activeDiscounts) {
#         this.activeDiscounts = activeDiscounts;
#         startNewOrder();
#     }
#
#     public void startNewOrder() { this.currentOrder = new Order(); }
#
#     public BigDecimal processPayment(BigDecimal paymentAmount) {
#         currentOrder.setPayment(paymentAmount);
#         return currentOrder.calculateChange();
#     }
#
#     public void addItemToOrder(Item item, int quantity) {
#         OrderItem orderItem = new OrderItem(item, quantity);
#         currentOrder.addItem(orderItem);
#         for (DiscountCampaign newDiscount : activeDiscounts) {
#             if (newDiscount.isApplicable(item)) {
#                 if (currentOrder.getAppliedDiscounts().containsKey(orderItem)) {
#                     DiscountCampaign existing =
#                             currentOrder.getAppliedDiscounts().get(orderItem);
#                     if (orderItem.calculatePriceWithDiscount(newDiscount)
#                             .compareTo(orderItem.calculatePriceWithDiscount(existing)) > 0) {
#                         currentOrder.applyDiscount(orderItem, newDiscount);
#                     }
#                 } else {
#                     currentOrder.applyDiscount(orderItem, newDiscount);
#                 }
#             }
#         }
#     }
#
#     public Receipt getReceipt() { return new Receipt(currentOrder); }
#     public BigDecimal getOrderTotal() { return currentOrder.calculateTotal(); }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">GroceryStoreSystem</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class GroceryStoreSystem {
#     private final Catalog catalog;
#     private final Inventory inventory;
#     private List<DiscountCampaign> activeDiscounts = new ArrayList<>();
#     private final Checkout checkout;
#
#     public GroceryStoreSystem() {
#         this.catalog = new Catalog();
#         this.inventory = new Inventory();
#         this.checkout = new Checkout(activeDiscounts);
#     }
#
#     public void addOrUpdateItem(Item item) { catalog.updateItem(item); }
#     public void updateInventory(String barcode, int count) { inventory.addStock(barcode, count); }
#     public void addDiscountCampaign(DiscountCampaign discount) { activeDiscounts.add(discount); }
#     public Item getItemByBarcode(String barcode) { return catalog.getItem(barcode); }
#     public void removeItem(String barcode) { catalog.removeItem(barcode); }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #bc6c25; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(188,108,37,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Deep Dive Topics</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(188,108,37,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #bc6c25;">Flexible Discount Criteria</span>
# </div>

# %% [markdown]
# What if the interviewer asks you to implement more complex composite discounts? We can enhance the design using the **Composite Pattern** for criteria and the **Decorator Pattern** for sequential calculations.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">Combining Multiple Criteria</span>
# </div>

# %% [markdown]
# CompositeCriteria allows combining multiple rules using logical AND:

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class CompositeCriteria implements DiscountCriteria {
#     private final List<DiscountCriteria> criteriaList;
#
#     public CompositeCriteria(List<DiscountCriteria> criteriaList) {
#         this.criteriaList = new ArrayList<>(criteriaList);
#     }
#
#     @Override
#     public boolean isApplicable(Item item) {
#         return criteriaList.stream().allMatch(c -> c.isApplicable(item));
#     }
#
#     public void addCriteria(DiscountCriteria criteria) { criteriaList.add(criteria); }
#     public void removeCriteria(DiscountCriteria criteria) { criteriaList.remove(criteria); }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">Layering Discount Calculations</span>
# </div>

# %% [markdown]
# Using the Decorator Pattern, we can layer multiple calculation strategies:

# %% [markdown]
# <div style="border-left: 4px solid #bc6c25; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class FixedDiscountDecorator implements DiscountCalculationStrategy {
#     private final DiscountCalculationStrategy strategy;
#     private final BigDecimal fixedAmount;
#
#     public FixedDiscountDecorator(DiscountCalculationStrategy strategy, BigDecimal fixedAmount) {
#         this.strategy = strategy;
#         this.fixedAmount = fixedAmount;
#     }
#
#     @Override
#     public BigDecimal calculateDiscountedPrice(BigDecimal originalPrice) {
#         return strategy.calculateDiscountedPrice(originalPrice).subtract(fixedAmount);
#     }
# }
#
# public class PercentageDiscountDecorator implements DiscountCalculationStrategy {
#     private final DiscountCalculationStrategy strategy;
#     private final BigDecimal additionalPercentage;
#
#     public PercentageDiscountDecorator(DiscountCalculationStrategy strategy,
#                                        BigDecimal additionalPercentage) {
#         this.strategy = strategy;
#         this.additionalPercentage = additionalPercentage;
#     }
#
#     @Override
#     public BigDecimal calculateDiscountedPrice(BigDecimal originalPrice) {
#         BigDecimal basePrice = strategy.calculateDiscountedPrice(originalPrice);
#         return basePrice.multiply(
#                 BigDecimal.ONE.subtract(additionalPercentage.divide(BigDecimal.valueOf(100))));
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #bc6c25; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(188,108,37,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Wrap Up</span>
# </div>

# %% [markdown]
# In this chapter, we designed a grocery store system step-by-step. The most important takeaway is the clear separation of concerns, where each component — Catalog, Inventory, Order, and DiscountCampaign — focuses on a specific responsibility.

# %% [markdown]
# In the deep dive section, we explored composite discounts and layering multiple calculation strategies using the Composite and Decorator patterns.

# %% [markdown]
# Congratulations on getting this far! Now give yourself a pat on the back. Good job!

# %% [markdown]
# <div style="border-left: 5px solid #bc6c25; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(188,108,37,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Further Reading: Decorator Design Pattern</span>
# </div>

# %% [markdown]
# Decorator is a structural design pattern that allows you to add new behaviors to an object by wrapping it in another object, without modifying the original object’s code.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">Problem</span>
# </div>

# %% [markdown]
# Imagine developing a text editor with styles like bold, italic, or underline. Creating subclasses for each combination leads to an explosion of classes.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">Solution</span>
# </div>

# %% [markdown]
# The Decorator Pattern creates decorator classes that implement the same interface and wrap the original object. Decorators can be stacked to combine behaviors.

# %% [markdown]
# ![Figure 14: Decorator design pattern](assets/image-9-14-7XXD62YS.svg)

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #bc6c25; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #bc6c25;">When to use</span>
# </div>

# %% [markdown]
# * When you need to add features dynamically at runtime without modifying code.
#
# * When subclassing results in too many combinations — composition is simpler.
