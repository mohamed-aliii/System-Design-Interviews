# %% [markdown]
# <!-- ByteByteGo inline UI theme: Code Editor / Algorithm -->
# <style>
#   /* Light mode overrides for subtitles - forced legibility without changing HTML source */
#   @media (prefers-color-scheme: light) {
#     .bbg-h2 { color: #1e293b !important; border-left-color: #16a34a !important; }
#     .bbg-h3 { color: #0284c7 !important; }
#     .bbg-h4 { color: #d97706 !important; }
#   }
#   body[data-jp-theme-light="true"] .bbg-h2,
#   .vscode-light .bbg-h2 {
#     color: #1e293b !important;
#     border-left-color: #16a34a !important;
#   }
#   body[data-jp-theme-light="true"] .bbg-h3,
#   .vscode-light .bbg-h3 {
#     color: #0284c7 !important;
#   }
#   body[data-jp-theme-light="true"] .bbg-h4,
#   .vscode-light .bbg-h4 {
#     color: #d97706 !important;
#   }
#
#
#   .bbg-banner,
#   .bbg-card,
#   .bbg-figure {
#     box-sizing: border-box;
#     width: 96%;
#     margin-left: auto;
#     margin-right: auto;
#   }
#
#   .bbg-card {
#     overflow-x: auto;
#     font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#     font-size: 17px;
#     line-height: 1.8;
#     letter-spacing: 0.01em;
#   }
#
#   .bbg-card table {
#     width: 100%;
#   }
# </style>

# %% [markdown]
# <div class="bbg-banner" style="background: linear-gradient(135deg, rgba(57,255,136,0.16), rgba(56,189,248,0.11)), linear-gradient(135deg, #0f172a, #111827); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); padding: 28px 50px; margin: 8px auto 26px; box-sizing: border-box; width: 96%;">
#   <div class="bbg-kicker" style="color: #39ff88; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px; font-weight: 700; letter-spacing: 0.08em; text-transform: uppercase;">Coding Interview Patterns</div>
#   <h1 style="color: #e5edf7; font-size: 34px; line-height: 1.15; margin: 10px 0 12px;">Lonely Integer</h1>
#   <div class="bbg-meta" style="color: #9fb0c4; display: flex; flex-wrap: wrap; gap: 10px; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px;">
#     <span class="bbg-pill" style="background: rgba(255,255,255,0.06); border: 1px solid rgba(255,255,255,0.10); border-radius: 999px; padding: 5px 10px;">Track: Coding Interview Patterns</span>
#     <span class="bbg-pill" style="background: rgba(255,255,255,0.06); border: 1px solid rgba(255,255,255,0.10); border-radius: 999px; padding: 5px 10px;">Chapter: Bit Manipulation</span>
#     <span class="bbg-pill" style="background: rgba(255,255,255,0.06); border: 1px solid rgba(255,255,255,0.10); border-radius: 999px; padding: 5px 10px;">Theme: Code Editor / Algorithm</span>
#   </div>
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Problem</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Given an integer array where each number occurs twice except for one of them, find the unique number.
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: #38bdf8; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Example:</h3>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# **Input:** `nums = [1, 3, 3, 2, 1]`
#
# **Output:** `2`
#
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: #38bdf8; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Constraints:</h3>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# - nums contains at least one element.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Intuition</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# **Hash Map** solution
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-18-02-1-M2A4JCS6.svg" alt="Diagram 1" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 1</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# A straightforward way to solve this problem is by using a **Hash Map**. The idea is to count the occurrences of each element in the array.
#
# We can do this by iterating through the array and increasing the frequency stored in the **Hash Map** of each element encountered in the array. Once populated, we can iterate through the **Hash Map** to find the element with a frequency of 1, which is our lonely integer.
#
# This approach takes $\mathcal{O}(n)$ time, but comes at the cost of $\mathcal{O}(n)$ space, where n denotes the length of the input array. Let’s see if there’s a way to solve this without additional data structures like a **Hash Map**.
#
# Sorting solution Another way to solve this problem is to sort the array first, then look for the lonely integer by iterating through the array, and comparing each element with its neighbors. The lonely integer will be the one that doesn’t have a duplicate next to it.
#
# This method takes $\mathcal{O}(n\log(n))$ time due to sorting, but has the benefit of not requiring any additional data structures (aside from any used during sorting). Is there a way we can achieve a linear **Time Complexity** while also maintaining constant space?
#
# Bit manipulation A way to avoid using additional space is with bit manipulation. The XOR operation in particular can be useful when handling duplicate integers.
#
# Recall the following two characteristics of the XOR operator:
#
# - a ^ a == 0
#
# - a ^ 0 == a
#
# As we can see, when we XOR two identical numbers, the result is 0. As each number except the lonely integer appears twice in the array, if we XOR all the numbers together, all pairs of identical numbers will cancel out to 0.
#
# This isolates the lonely integer: once all duplicate elements cancel to 0, XORing 0 with the lonely integer gives us the lonely integer. This works independently of where the numbers are located in the array, as XOR follows the commutative and associative properties:
#
# - Commutative property: a ^ b == b ^ a
#
# - Associative property: (a ^ b) ^ c == a ^ (b ^ c)
#
# So, as long as two of the same numbers exist in the array, they will get canceled out when we XOR all the elements. An example of this is shown below:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-18-02-3-ST7E4JWW.svg" alt="Diagram 3" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 3</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# This allows us to identify the lonely integer in **Linear Time** without using extra space.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Try it yourself</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Write your solution to the problem before checking the reference implementation. Open Code Editor
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Implementation</h2>

# %% [markdown]
# <h4 class="bbg-h4" style="color: #f59e0b; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Implementation</h4>

# %%
from typing import List

def lonely_integer(nums: List[int]) -> int:
    res = 0
    # XOR each element of the array so that duplicate values will cancel each other
    # out (x ^ x == 0).
    for num in nums:
        res ^= num
    # 'res' will store the lonely integer because it would not have been canceled out
    # by any duplicate.
    return res

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Complexity Analysis</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# **Time Complexity**: The **Time Complexity** of lonely_integer is $\mathcal{O}(n)$ because we perform a constant-time XOR operation on each element in nums.
#
#  **Space Complexity**: The **Space Complexity** is $\mathcal{O}(1)$.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Additional Diagrams</h2>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-18-02-2-KHYDB73Q.svg" alt="Diagram 2" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 2</figcaption>
# </figure>
