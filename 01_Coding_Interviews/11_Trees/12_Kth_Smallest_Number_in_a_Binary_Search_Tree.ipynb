# %% [markdown]
# <!-- ByteByteGo inline UI theme: Code Editor / Algorithm -->
# <style>
#   /* Theme-aware notebook UI colors for VS Code, Jupyter, and browser renderers. */
#   :root {
#     --bbg-title-color: var(--vscode-foreground, var(--jp-content-font-color1, CanvasText));
#     --bbg-muted-color: var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b));
#     --bbg-accent-green: var(--vscode-charts-green, var(--jp-success-color1, #16a34a));
#     --bbg-h3-color: var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb));
#     --bbg-h4-color: var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309));
#     --bbg-pill-bg: rgba(100, 116, 139, 0.08);
#     --bbg-pill-border: rgba(100, 116, 139, 0.18);
#   }
#   @media (prefers-color-scheme: dark) {
#     :root {
#       --bbg-title-color: #e5edf7;
#       --bbg-muted-color: #9fb0c4;
#       --bbg-accent-green: #39ff88;
#       --bbg-h3-color: #38bdf8;
#       --bbg-h4-color: #f59e0b;
#       --bbg-pill-bg: rgba(255, 255, 255, 0.06);
#       --bbg-pill-border: rgba(255, 255, 255, 0.10);
#     }
#   }
#   body[data-jp-theme-light="true"],
#   .vscode-light {
#     --bbg-title-color: #1e293b;
#     --bbg-muted-color: #64748b;
#     --bbg-accent-green: #16a34a;
#     --bbg-h3-color: #2563eb;
#     --bbg-h4-color: #b45309;
#     --bbg-pill-bg: rgba(100, 116, 139, 0.08);
#     --bbg-pill-border: rgba(100, 116, 139, 0.18);
#   }
#   body[data-jp-theme-dark="true"],
#   .vscode-dark {
#     --bbg-title-color: #e5edf7;
#     --bbg-muted-color: #9fb0c4;
#     --bbg-accent-green: #39ff88;
#     --bbg-h3-color: #38bdf8;
#     --bbg-h4-color: #f59e0b;
#     --bbg-pill-bg: rgba(255, 255, 255, 0.06);
#     --bbg-pill-border: rgba(255, 255, 255, 0.10);
#   }
#   .bbg-h2 {
#     color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))) !important;
#     border-left-color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))) !important;
#   }
#   .bbg-h3 { color: var(--bbg-h3-color, var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb))) !important; }
#   .bbg-h4 { color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))) !important; }
#   .bbg-kicker { color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))) !important; }
#   .bbg-meta { color: var(--bbg-muted-color, var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b))) !important; }
#   .bbg-pill {
#     background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)) !important;
#     border-color: var(--bbg-pill-border, rgba(100, 116, 139, 0.18)) !important;
#   }
#
#
#   .bbg-banner,
#   .bbg-card,
#   .bbg-figure {
#     box-sizing: border-box;
#     width: 96%;
#     margin-left: auto;
#     margin-right: auto;
#   }
#
#   .bbg-card {
#     overflow-x: auto;
#     font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#     font-size: 17px;
#     line-height: 1.8;
#     letter-spacing: 0.01em;
#   }
#
#   .bbg-card table {
#     width: 100%;
#   }
# </style>

# %% [markdown]
# <div class="bbg-banner" style="background: linear-gradient(135deg, rgba(57,255,136,0.16), rgba(56,189,248,0.11)), linear-gradient(135deg, #0f172a, #111827); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); padding: 28px 50px; margin: 8px auto 26px; box-sizing: border-box; width: 96%;">
#   <div class="bbg-kicker" style="color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a)); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px; font-weight: 700; letter-spacing: 0.08em; text-transform: uppercase;">Coding Interview Patterns</div>
#   <h1 style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); font-size: 34px; line-height: 1.15; margin: 10px 0 12px;">Kth Smallest Number in a Binary Search Tree</h1>
#   <div class="bbg-meta" style="color: var(--bbg-muted-color, var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b)); display: flex; flex-wrap: wrap; gap: 10px; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px;">
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Track: Coding Interview Patterns</span>
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Chapter: Trees</span>
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Theme: Code Editor / Algorithm</span>
#   </div>
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Problem</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Given the root of a **Binary Search** **Tree** (BST) and an integer k, find the k th smallest node value.
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: var(--bbg-h3-color, var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Example:</h3>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Given the BST below and k = 5:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-11-11-1-PLKDARO3.svg" alt="Diagram 1" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 1</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Output: 6
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: var(--bbg-h3-color, var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Constraints:</h3>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# - n ≥ 1, where n denotes the number of nodes in the **Tree**.
#
# - 1 ≤ k ≤ n
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Intuition - Recursive</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# A naive approach to this problem is to traverse the **Tree** and store all the nodes in an array, sort the array, and return the kth element. This approach, however, does not take advantage of the fact that we're dealing with a BST. Consider again the BST from the example:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-11-11-1-PLKDARO3.svg" alt="Diagram 2" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 2</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# We know that in a BST, each node’s value is larger than all the nodes to its left and smaller than all the nodes to its right. This structure means that BSTs inherently possess a sorted order.
#
# Given this, it should be possible to construct a sorted array of the **Tree**'s values by traversing the **Tree**, without the need for additional sorting. We now need a method to traverse the binary **Tree** that allows us to encounter the nodes in their sorted order.
#
# What are our options? We can immediately rule out any traversal algorithms that process the root node first, such as breadth-first search and preorder traversal, since the root node is not guaranteed to have the smallest value in a BST.
#
# This also indicates that we need an algorithm that starts with the leftmost node since this is always the smallest node in a BST. Additionally, the algorithm should end at the rightmost node since this would be the largest node.
#
# This leads us to an ideal traversal algorithm: inorder traversal, where for each node, the left subtree is processed first, followed by the current node, and then the right subtree.
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-11-11-2-IG2V6AJD.svg" alt="Diagram 3" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 3</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# To build the sorted list of values using inorder traversal, we can design a recursive function. When called on the root node, it returns a sorted list of all the values in the BST.
#
# When the function is called for any node during the recursive process, it constructs a sorted list of the values in the subtree rooting from that node. This is achieved by first obtaining the sorted values from its left subtree, then adding the current node's value, and finally appending the sorted values from its right subtree.
#
# This process is carried out through recursive calls to the left and right children. Once we have the full list of sorted values, we can simply return the value at the ( k - 1)th index to get the k th smallest value.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Try it yourself</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Write your solution to the problem before checking the reference implementation. Open Code Editor
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Implementation - Recursive</h2>

# %% [markdown]
# <h4 class="bbg-h4" style="color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Snippet</h4>

# %%
from typing import List

from ds import TreeNode

def kth_smallest_number_in_BST_recursive(root: TreeNode, k: int) -> int:
    sorted_list = inorder(root)
    return sorted_list[k - 1]

# Inorder traversal function to attain a sorted list of nodes from the BST.
def inorder(node: TreeNode) -> List[int]:
    if not node:
        return []
    return inorder(node.left) + [node.val] + inorder(node.right)

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Complexity Analysis</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# **Time Complexity**: The **Time Complexity** of kth_smallest_number_in_BST_recursive is $\mathcal{O}(n)$, where n denotes the number of nodes in the **Tree**. This is because we need to traverse through all n nodes of the **Tree** to attain the sorted list. **Space Complexity**: The **Space Complexity** is $\mathcal{O}(n)$ due to the space taken up by sorted_list, as well as the recursive call **Stack**, which can grow as large as the height of the binary **Tree**. The largest possible height of a binary **Tree** is n.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Intuition - Iterative</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Since we only need the kth smallest value, storing all n values in a list might not be necessary. Ideally, we’d like to find a way to traverse through k nodes instead of n.
#
# How can we modify our approach to achieve this? If we had a way to stop inorder traversal once we've reached the kth node in the traversal, we would land on our answer.
#
# An iterative approach would allow for this since we’d be able to exit traversal once we’ve reached the kth node — something that’s quite difficult to achieve using **Recursion**. We know inorder traversal is a DFS algorithm and that DFS algorithms can be implemented iteratively using a **Stack**.
#
# Let’s explore this idea further. Consider what happened during recursive inorder traversal in the previous approach:
#
# - Make a recursive call to the left subtree.
#
# - Process the current node.
#
# - Make a recursive call to the right subtree.
#
# Let’s replicate the above steps iteratively using a **Stack**.
#
# - Move as far left as possible, adding each node to the **Stack** as we move left.
#
# - We do this because, at the start of each recursive call in the recursive approach, a new call is made to the current node’s left subtree, continuing until the base case (a null node) is reached. This implies that to mimic this process iteratively, we’ll need to move as far left as possible.
#
# - The reason we push nodes onto the **Stack** as we go is so they can be processed later.
#
# The code snippet for this can be seen below:
#
# </div>

# %% [markdown]
# <h4 class="bbg-h4" style="color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Snippet</h4>

# %%
while node:
    stack.append(node)
    node = node.left

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# - Once we can no longer move left, we pop the node off the top of the **Stack**. Let's call it the current node. Initially, this node will represent the smallest node. After this, the current node will subsequently represent the next smallest node, and so on until we reach the kth smallest node.
#
# - Decrement k, indicating that we now have one less node to visit until we reach the k th smallest node.
#
# - Once k == 0, we found the k th smallest node. Return the value of this node.
#
# - Move to the current node’s right child.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Try it yourself</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Write your solution to the problem before checking the reference implementation. Open Code Editor
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Implementation - Iterative</h2>

# %% [markdown]
# <h4 class="bbg-h4" style="color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Snippet</h4>

# %%
def kth_smallest_number_in_BST_iterative(root: TreeNode, k: int) -> int:
    stack = []
    node = root
    while stack or node:
        # Move to the leftmost node and add nodes to the stack as we go so they
        # can be processed in future iterations.
        while node:
            stack.append(node)
            node = node.left
        # Pop the top node from the stack to process it, and decrement 'k'.
        node = stack.pop()
        k -= 1
        # If we have processed 'k' nodes, return the value of the 'k'th smallest
        # node.
        if k == 0:
            return node.val
        # Move to the right subtree.
        node = node.right

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Complexity Analysis</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# **Time Complexity**: The **Time Complexity** of kth_smallest_number_in_BST_iterative is $\mathcal{O}(k+h)$, where h denotes the height of the **Tree**. Here’s why:
#
# - Iterative inorder traversal ensures we traverse k nodes, which takes at least $\mathcal{O}(k)$ time.
#
# - Additionally, traversing to the leftmost node takes up to $\mathcal{O}(h)$ time, which should be considered separately since it’s possible that h > k. In the **Worst Case**, the height of the **Tree** is n, resulting in a **Time Complexity** of $\mathcal{O}(n)$, where n denotes the number of nodes in the **Tree**.
#
# **Space Complexity**: The **Space Complexity** is $\mathcal{O}(h)$ since the **Stack** can store up to $\mathcal{O}(h)$ during the traversal to the leftmost node. In the **Worst Case**, the height of the **Tree** is n, resulting in a **Space Complexity** of $\mathcal{O}(n)$.
#
# </div>
