# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon { font-size: 22px !important; line-height: 1.8 !important; }
# .jp-RenderedHTMLCommon h2 { font-size: 1.7em !important; border-left: 5px solid #2d6a4f !important; padding: 10px 0 10px 18px !important; margin-top: 40px !important; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%) !important; border-radius: 4px !important; }
# .jp-RenderedHTMLCommon h3 { font-size: 1.35em !important; border-bottom: 2px solid rgba(45,106,79,0.3) !important; padding-bottom: 8px !important; margin-top: 30px !important; color: #2d6a4f !important; }
# .jp-RenderedHTMLCommon h4 { font-size: 1.15em !important; font-style: italic !important; color: #2d6a4f !important; margin-top: 22px !important; }
# </style>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #081c15 0%, #1b4332 50%, #2d6a4f 100%); padding: 40px 45px; border-radius: 16px; margin-bottom: 30px; border: 1px solid rgba(42,157,143,0.15); max-width: 95%; overflow: hidden; box-sizing: border-box;">
#   <div style="font-size: 15px; font-weight: 600; letter-spacing: 3px; text-transform: uppercase; color: #2d6a4f; margin-bottom: 8px;">Chapter 06</div>
#   <div style="font-size: 36px; font-weight: 800; color: #ffffff; margin-bottom: 16px; line-height: 1.2;">Design a Unix File Search System</div>
#   <div style="width: 60px; height: 4px; background: linear-gradient(90deg, #2d6a4f, rgba(42,157,143,0.5)); border-radius: 2px; margin-bottom: 18px;"></div>
#   <div style="font-size: 17px; color: #b0bec5; line-height: 1.6;">Object-Oriented Design Interview Question</div>
#   <div style="margin-top: 20px; font-size: 13px; color: #546e7a;">Source: ByteByteGo — Object-Oriented Design Interview</div>
# </div>

# %% [markdown]
# In this chapter, we will explore the design of a Unix File Search system. The goal is to design classes that represent abstractions of the key entities in a file search system, such as directories, files, and filter criteria. We’ll aim to create a clear and functional structure that captures the essential interactions between these components, ensuring the search system is intuitive and scalable.

# %% [markdown]
# ![Figure 1: Unix file search](assets/image-6-1-GZDKBPWN.png)

# %% [markdown]
# Let’s gather the specific requirements through a simulated interview scenario.

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Requirements Gathering</span>
# </div>

# %% [markdown]
# Here is an example of a typical prompt an interviewer might give:

# %% [markdown]
# > “Imagine you’re a developer trying to find specific files on a Unix system, like files owned by a user, or text files matching a pattern, buried deep in a directory structure. You run a search command, specify your criteria, and the system returns matching files quickly. Behind the scenes, it’s recursively traversing directories, evaluating file attributes, and applying your filters efficiently. Let’s design a Unix File Search system that handles this process.”

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Requirements clarification</span>
# </div>

# %% [markdown]
# Here is an example of how a conversation between a candidate and an interviewer might unfold:

# %% [markdown]
# <div style="border: 1px solid rgba(45,106,79,0.3); border-radius: 8px; margin: 28px 0; overflow: hidden; font-family: system-ui, -apple-system, sans-serif;">
#   <div style="background: rgba(45,106,79,0.08); padding: 10px 20px; border-bottom: 1px solid rgba(45,106,79,0.3); display: flex; align-items: center; gap: 8px;">
#     <span style="font-size: 1.1em;">&#128483;</span>
#     <span style="font-size: 0.85em; font-weight: 700; color: #2d6a4f; text-transform: uppercase; letter-spacing: 1.5px;">Interview Transcript</span>
#   </div>
#   <div style="padding: 24px 20px 24px 28px; position: relative;">
#     <div style="position: absolute; left: 38px; top: 24px; bottom: 24px; width: 2px; background: rgba(45,106,79,0.3);"></div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">What attributes does the find command use to search for files?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">It could be based on criteria like size, file type, filename, and owner.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Does it need to handle directories?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, directories are considered as files too, with a distinct file type.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">What types of comparisons does the command support?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">That depends on the type of attribute. For strings, we support ‘equals’ and ‘regex match’. For numbers, we support ‘greater than’, ‘equals’, and ‘less than’.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Can we combine multiple criteria, even on the same attribute?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, with multiple criteria, using ‘and’, ‘or’, and ‘not’ conditions.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">I assume we’re designing a system to search a directory and its sub-directories, returning files that match the given conditions.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, that’s a fair assumption.</div>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Constructing concrete examples</span>
# </div>

# %% [markdown]
# With the requirements in hand, let’s see them in action through some real-world command-line searches:

# %% [markdown]
# * **Simple Search**: Find files recursively within `/` where `size > 10`.
#
# * **Complex Search**: Find files recursively within `/` where `((size > 10 and size < 1000 and owner = "alice") or (size > 1000 and !(filename matches /prefix.*/)))`.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Requirements</span>
# </div>

# %% [markdown]
# Based on the questions and answers, the following functional requirements can be identified:

# %% [markdown]
# * The search system can search for files based on attributes such as size, type, filename, and owner.
#
# * The search system supports comparison types depending on the attribute: ‘equals’ and ‘regex match’ for strings, and ‘greater than’, ‘equals’, and ‘less than’ for numbers.
#
# * The system can combine multiple search criteria using logical operators (and, or, not).
#
# * The file search system can perform recursive searches within directories.
#
# * The search system can apply search criteria to directories as well as files.

# %% [markdown]
# Below are the non-functional requirements:

# %% [markdown]
# * **Scalability**: Efficiently handle large directory trees with thousands or millions of files.
#
# * **Extensibility**: Support adding new attributes and comparison operators without altering core logic.
#
# * **Separation of concerns**: Keep traversal logic separate from filtering logic.

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Identify Core Objects</span>
# </div>

# %% [markdown]
# Let’s break it down into core objects, each with a clear role:

# %% [markdown]
# * **FileSearch**: The central entity managing the search process. It recursively traverses the filesystem from a starting File (directory) and returns matches based on a FileSearchCriteria object.
#
# * **File**: Models a file or directory in the filesystem, storing attributes like size, type, filename, and owner.
#
# * **FileSearchCriteria**: Encapsulates a search condition and determines whether a given File matches it by delegating to a Predicate.
#
# * **Predicate**: An interface defining the contract for evaluating whether a File matches a condition, enabling both simple checks and composite conditions.
#
# * **SimplePredicate**: Implements Predicate to compare one file attribute against a value with an operator.
#
# * **CompositePredicate**: Extends Predicate for combining conditions (AND, OR, NOT).
#
# * **ComparisonOperator**: An interface defining how attribute values are compared, with implementations like EqualsOperator, RegexMatchOperator, GreaterThanOperator, and LessThanOperator.

# %% [markdown]
# **Design choice**: The File object represents files and directories as a single entity. This aligns with the Unix principle that treats everything as a file for uniform handling.

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Design Class Diagram</span>
# </div>

# %% [markdown]
# We’ve mapped out the core objects. Now let’s define their classes.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">File</span>
# </div>

# %% [markdown]
# We define a custom File class as the core entity, capturing key attributes and supporting hierarchical traversal. It’s paired with a FileAttribute enum for attributes used in search conditions.

# %% [markdown]
# ![Figure 2: File class](assets/image-6-2-75BM2SDZ.svg)

# %% [markdown]
# **Design choice**: We define FileAttribute as an enum to provide a fixed, type-safe set of attributes for search conditions. Adding a new attribute requires simply extending the enum.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">FileSearch</span>
# </div>

# %% [markdown]
# The FileSearch class is responsible for traversing the file system from a given File, using a FileSearchCriteria object to select matching files and return them. By separating traversal from filtering logic, the design remains modular.

# %% [markdown]
# ![Figure 3: FileSearch class](assets/image-6-3-A3COBR3Q.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">FileSearchCriteria</span>
# </div>

# %% [markdown]
# The FileSearchCriteria class decides which files match our search by connecting FileSearch to Predicate. It tells FileSearch what qualifies as a match.

# %% [markdown]
# ![Figure 4: FileSearchCriteria class](assets/image-6-4-GMJOJPIP.svg)

# %% [markdown]
# **Design choice**: We designed FileSearchCriteria to delegate to a Predicate, keeping responsibilities clean and modular. This enables changing or combining filtering logic without modifying FileSearch or FileSearchCriteria.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Predicate and SimplePredicate</span>
# </div>

# %% [markdown]
# The Predicate interface is the foundation for evaluating files. SimplePredicate evaluates a single file attribute against a specified value using a comparison operator.

# %% [markdown]
# ![Figure 5: Predicate interface and SimplePredicate](assets/image-6-5-HE7Y2UUG.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">ComparisonOperator</span>
# </div>

# %% [markdown]
# The ComparisonOperator interface defines a contract for comparing a file’s attribute value to an expected value. Concrete implementations include:

# %% [markdown]
# * **EqualsOperator**: confirms if two attribute values are the same.
#
# * **GreaterThanOperator**: verifies if one attribute value is larger.
#
# * **LessThanOperator**: ensures one attribute value is smaller.
#
# * **RegexMatchOperator**: evaluates whether a string attribute matches a regular expression pattern.

# %% [markdown]
# ![Figure 6: ComparisonOperator interface and concrete classes](assets/image-6-6-CLM3LGF5.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Composite Predicate</span>
# </div>

# %% [markdown]
# With SimplePredicate in place, we use the Composite design pattern to build complex predicates from simpler ones. Consider a search like:

# %% [markdown]
# `Find files where ((size > 10 and size < 1000 and owner = "alice") or (size > 1000 and !(filename matches /prefix.*/)))`

# %% [markdown]
# This tree-like hierarchy needs a systematic way to evaluate files:

# %% [markdown]
# ![Figure 7: Tree evaluation](assets/image-6-7-O4ALO4E7.svg)

# %% [markdown]
# We define CompositePredicate with concrete implementations: **AndPredicate**, **OrPredicate**, and **NotPredicate**.

# %% [markdown]
# ![Figure 8: CompositePredicate interface and concrete classes](assets/image-6-8-M7TNT6W6.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Complete Class Diagram</span>
# </div>

# %% [markdown]
# Having built our classes, here is the complete system in a UML class diagram:

# %% [markdown]
# ![Figure 9: Class Diagram of File Search](assets/image-6-9-KA2ZDXCM.svg)

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Code - Unix File Search</span>
# </div>

# %% [markdown]
# Now let’s implement the core components.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">File</span>
# </div>

# %% [markdown]
# The File class models both files and directories, encapsulating attributes such as size, name, owner, and a boolean flag indicating directory status.

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class File {
#     private final boolean isDirectory;
#     private final int size;
#     private final String owner;
#     private final String filename;
#     private final Set<File> entries = new HashSet<>();
#
#     public File(final boolean isDirectory, final int size,
#                 final String owner, final String filename) {
#         this.isDirectory = isDirectory;
#         this.size = size;
#         this.owner = owner;
#         this.filename = filename;
#     }
#
#     public Object extract(final FileAttribute attributeName) {
#         switch (attributeName) {
#             case SIZE -> { return size; }
#             case OWNER -> { return owner; }
#             case IS_DIRECTORY -> { return isDirectory; }
#             case FILENAME -> { return filename; }
#         }
#         throw new IllegalArgumentException("invalid filter criteria type");
#     }
#
#     public void addEntry(final File entry) { entries.add(entry); }
#     // getter methods omitted for brevity
# }
#
# public enum FileAttribute {
#     IS_DIRECTORY, SIZE, OWNER, FILENAME
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Predicate</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public interface Predicate {
#     boolean isMatch(final File inputFile);
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">ComparisonOperator</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public interface ComparisonOperator<T> {
#     boolean isMatch(final T attributeValue, final T expectedValue);
# }
#
# public class EqualsOperator<T> implements ComparisonOperator<T> {
#     @Override
#     public boolean isMatch(final T attributeValue, final T expectedValue) {
#         return Objects.equals(attributeValue, expectedValue);
#     }
# }
#
# class GreaterThanOperator<T extends Number> implements ComparisonOperator<T> {
#     @Override
#     public boolean isMatch(final T attributeValue, final T expectedValue) {
#         return Double.compare(attributeValue.doubleValue(), expectedValue.doubleValue()) > 0;
#     }
# }
#
# class LessThanOperator<T extends Number> implements ComparisonOperator<T> {
#     @Override
#     public boolean isMatch(final T attributeValue, final T expectedValue) {
#         return Double.compare(attributeValue.doubleValue(), expectedValue.doubleValue()) < 0;
#     }
# }
#
# public class RegexMatchOperator<T extends String> implements ComparisonOperator<T> {
#     @Override
#     public boolean isMatch(final T attributeValue, final T expectedValue) {
#         return Pattern.compile(expectedValue).matcher(attributeValue).matches();
#     }
# }
# ```
#
# </div>

# %% [markdown]
# **Implementation choice**: We leverage generics (`<T>`) to enforce type safety at compile time, ensuring attribute values and expected values align in type.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">SimplePredicate</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class SimplePredicate<T> implements Predicate {
#     private final FileAttribute attributeName;
#     private final ComparisonOperator<T> operator;
#     T expectedValue;
#
#     public SimplePredicate(final FileAttribute attributeName,
#                            final ComparisonOperator<T> operator,
#                            final T expectedValue) {
#         this.attributeName = attributeName;
#         this.operator = operator;
#         this.expectedValue = expectedValue;
#     }
#
#     @Override
#     public boolean isMatch(final File inputFile) {
#         Object actualValue = inputFile.extract(attributeName);
#         if (expectedValue.getClass().isInstance(actualValue)) {
#             return operator.isMatch((T) actualValue, expectedValue);
#         } else {
#             return false;
#         }
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">CompositePredicate</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public interface CompositePredicate extends Predicate {
#     // Marker interface for composite predicates (AND, OR, NOT)
# }
#
# public class AndPredicate implements CompositePredicate {
#     private final List<Predicate> operands;
#     public AndPredicate(final List<Predicate> operands) { this.operands = operands; }
#     @Override
#     public boolean isMatch(final File inputFile) {
#         return operands.stream().allMatch(p -> p.isMatch(inputFile));
#     }
# }
#
# public class OrPredicate implements CompositePredicate {
#     private final List<Predicate> operands;
#     public OrPredicate(final List<Predicate> operands) { this.operands = operands; }
#     @Override
#     public boolean isMatch(final File inputFile) {
#         return operands.stream().anyMatch(p -> p.isMatch(inputFile));
#     }
# }
#
# public class NotPredicate implements CompositePredicate {
#     private final Predicate operand;
#     public NotPredicate(final Predicate operand) { this.operand = operand; }
#     @Override
#     public boolean isMatch(final File inputFile) {
#         return !operand.isMatch(inputFile);
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">FileSearchCriteria</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class FileSearchCriteria {
#     private final Predicate predicate;
#
#     public FileSearchCriteria(final Predicate predicate) {
#         this.predicate = predicate;
#     }
#
#     public boolean isMatch(final File inputFile) {
#         return predicate.isMatch(inputFile);
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">FileSearch</span>
# </div>

# %% [markdown]
# The FileSearch class orchestrates the search using a stack-based approach to explore directories efficiently.

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class FileSearch {
#     public List<File> search(final File root, final FileSearchCriteria criteria) {
#         final List<File> result = new ArrayList<>();
#         final ArrayDeque<File> recursionStack = new ArrayDeque<>();
#         recursionStack.add(root);
#         while (!recursionStack.isEmpty()) {
#             File next = recursionStack.pop();
#             if (criteria.isMatch(next)) {
#                 result.add(next);
#             }
#             for (File entry : next.getEntries()) {
#                 recursionStack.push(entry);
#             }
#         }
#         return result;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# **Implementation choice**: We opted for a stack over recursive calls to prevent stack overflow in deep filesystems.

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Deep Dive Topic</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">File search test</span>
# </div>

# %% [markdown]
# Here’s a test case for the condition “non-directories owned by ‘ge.*’”:

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class FileSearchTest {
#     @Test
#     public void testFileSearch() {
#         final File root = new File(true, 0, "adam", "root");
#         final File a = new File(false, 2000, "adam", "a");
#         final File b = new File(false, 3000, "george", "b");
#         root.addEntry(a);
#         root.addEntry(b);
#
#         final FileSearchCriteria criteria =
#                 new FileSearchCriteria(
#                         new AndPredicate(
#                                 List.of(
#                                         new SimplePredicate<>(
#                                                 FileAttribute.IS_DIRECTORY,
#                                                 new EqualsOperator<>(),
#                                                 false),
#                                         new SimplePredicate<>(
#                                                 FileAttribute.OWNER,
#                                                 new RegexMatchOperator<>(),
#                                                 "ge.*"))));
#
#         final FileSearch fileSearch = new FileSearch();
#         final List<File> result = fileSearch.search(root, criteria);
#
#         assertEquals(1, result.size());
#         assertEquals("b", result.get(0).getFilename());
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Wrap Up</span>
# </div>

# %% [markdown]
# With the UNIX file search system fully implemented and tested, the system’s maintainability and extensibility are ensured by the clear division of responsibilities among File, FileSearch, FileSearchCriteria, and Predicate.

# %% [markdown]
# Our choices, such as separating FileSearch from FileSearchCriteria and using generics in ComparisonOperator, improve scalability and maintain type safety. We could have merged FileSearchCriteria with Predicate, but this would blur their distinct roles.

# %% [markdown]
# Congratulations on getting this far! Now give yourself a pat on the back. Good job!

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Further Reading: Composite Design Pattern</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Composite design pattern</span>
# </div>

# %% [markdown]
# Composite is a structural pattern that lets you organize objects into tree structures and then handle these structures as if they were individual objects.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #2d6a4f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #2d6a4f;">Problem</span>
# </div>

# %% [markdown]
# Imagine you have two types of objects: Files and Folders. A Folder can contain several Files as well as many smaller Folders. How would you find all items matching a specific condition across this structure?

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #2d6a4f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #2d6a4f;">Solution</span>
# </div>

# %% [markdown]
# The Composite pattern suggests that we work with Files and Folders through a common interface that declares a method for checking conditions.

# %% [markdown]
# ![Figure 10: Composite design pattern](assets/image-6-10-OUZY7I67.svg)

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #2d6a4f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #2d6a4f;">When to use</span>
# </div>

# %% [markdown]
# * You need to build a tree-like object structure.
#
# * When you want the client code to handle both simple and complex elements uniformly.
