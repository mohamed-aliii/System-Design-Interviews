# %% [markdown]
# <!-- ByteByteGo inline UI theme: Code Editor / Algorithm -->
# <style>
#   /* Theme-aware notebook UI colors for VS Code, Jupyter, and browser renderers. */
#   :root {
#     --bbg-title-color: var(--vscode-foreground, var(--jp-content-font-color1, CanvasText));
#     --bbg-muted-color: var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b));
#     --bbg-accent-green: var(--vscode-charts-green, var(--jp-success-color1, #16a34a));
#     --bbg-h3-color: var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb));
#     --bbg-h4-color: var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309));
#     --bbg-pill-bg: rgba(100, 116, 139, 0.08);
#     --bbg-pill-border: rgba(100, 116, 139, 0.18);
#   }
#   @media (prefers-color-scheme: dark) {
#     :root {
#       --bbg-title-color: #e5edf7;
#       --bbg-muted-color: #9fb0c4;
#       --bbg-accent-green: #39ff88;
#       --bbg-h3-color: #38bdf8;
#       --bbg-h4-color: #f59e0b;
#       --bbg-pill-bg: rgba(255, 255, 255, 0.06);
#       --bbg-pill-border: rgba(255, 255, 255, 0.10);
#     }
#   }
#   body[data-jp-theme-light="true"],
#   .vscode-light {
#     --bbg-title-color: #1e293b;
#     --bbg-muted-color: #64748b;
#     --bbg-accent-green: #16a34a;
#     --bbg-h3-color: #2563eb;
#     --bbg-h4-color: #b45309;
#     --bbg-pill-bg: rgba(100, 116, 139, 0.08);
#     --bbg-pill-border: rgba(100, 116, 139, 0.18);
#   }
#   body[data-jp-theme-dark="true"],
#   .vscode-dark {
#     --bbg-title-color: #e5edf7;
#     --bbg-muted-color: #9fb0c4;
#     --bbg-accent-green: #39ff88;
#     --bbg-h3-color: #38bdf8;
#     --bbg-h4-color: #f59e0b;
#     --bbg-pill-bg: rgba(255, 255, 255, 0.06);
#     --bbg-pill-border: rgba(255, 255, 255, 0.10);
#   }
#   .bbg-h2 {
#     color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))) !important;
#     border-left-color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))) !important;
#   }
#   .bbg-h3 { color: var(--bbg-h3-color, var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb))) !important; }
#   .bbg-h4 { color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))) !important; }
#   .bbg-kicker { color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))) !important; }
#   .bbg-meta { color: var(--bbg-muted-color, var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b))) !important; }
#   .bbg-pill {
#     background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)) !important;
#     border-color: var(--bbg-pill-border, rgba(100, 116, 139, 0.18)) !important;
#   }
#
#
#   .bbg-banner,
#   .bbg-card,
#   .bbg-figure {
#     box-sizing: border-box;
#     width: 96%;
#     margin-left: auto;
#     margin-right: auto;
#   }
#
#   .bbg-card {
#     overflow-x: auto;
#     font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#     font-size: 17px;
#     line-height: 1.8;
#     letter-spacing: 0.01em;
#   }
#
#   .bbg-card table {
#     width: 100%;
#   }
# </style>

# %% [markdown]
# <div class="bbg-banner" style="font-size: 18px; line-height: 1.75; font-family: Inter, ui-sans-serif, system-ui, sans-serif; letter-spacing: 0;">
#
#   <div class="bbg-kicker" style="color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a)); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px; font-weight: 700; letter-spacing: 0.08em; text-transform: uppercase;">Coding Interview Patterns
#
# </div>
#   <h1 style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); font-size: 34px; line-height: 1.15; margin: 10px 0 12px;">Triplet Sum</h1>
#   <div class="bbg-meta" style="color: var(--bbg-muted-color, var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b)); display: flex; flex-wrap: wrap; gap: 10px; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px;">
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Track: Coding Interview Patterns</span>
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Chapter: Two Pointers</span>
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Theme: Code Editor / Algorithm</span>
#
#
# </div>
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Problem</h2>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# Given an array of integers, return all triplets [a, b, c] such that a + b + c = 0. The solution must not contain duplicate triplets (e.g., [1, 2, 3] and [2, 3, 1] are considered duplicates). If no such triplets are found, return an empty array.
#
# Each triplet can be arranged in any order, and the output can be returned in any order.
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: var(--bbg-h3-color, var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Example:</h3>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# Input: nums = [0, -1, 2, -3, 1]
#
# Output: [[-3, 1, 2], [-1, 0, 1]]
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Intuition</h2>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# A brute force solution involves checking every possible triplet in the array to see if they sum to zero. This can be done using three nested loops, iterating through each combination of three elements.
#
# Duplicate triplets can be avoided by sorting each triplet, which ensures that identical triplets with different representations (e.g., [1, 3, 2] and [3, 2, 1]) are ordered consistently (e.g., [1, 2, 3]). Once sorted, we can add these triplets to a hash set. This way, if the same triplet is encountered again, the hash set will only keep one instance. Below is the code snippet for this approach:
#
# </div>

# %% [markdown]
# <h4 class="bbg-h4" style="color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Brute Force Python</h4>

# %%
from typing import List

def triplet_sum_brute_force(nums: List[int]) -> List[List[int]]:
    n = len(nums)
    # Use a hash set to ensure we don't add duplicate triplets.
    triplets = set()
    # Iterate through the indexes of all triplets.
    for i in range(n):
        for j in range(i + 1, n):
            for k in range(j + 1, n):
                if nums[i] + nums[j] + nums[k] == 0:
                    # Sort the triplet before including it in the hash set.
                    triplet = tuple(sorted([nums[i], nums[j], nums[k]]))
                    triplets.add(triplet)
    return [list(triplet) for triplet in triplets]

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# This solution is quite inefficient with a time complexity of $\mathcal{O}(n^3)$, where n denotes the length of the input array. How can we do better?
#
# Let’s see if we can find at least one triplet that sums to 0. Notice that if we fix one of the numbers in a triplet, the problem can be reduced to finding the other two. This leads to the following observation:
#
# For any triplet [a, b, c], if we fix &#x27;a&#x27;, we can focus on finding a pair [b, c] that sums to &#x27;-a&#x27; (a + b + c = 0 → b + c = -a).
#
# Sound familiar? That&#x27;s because the problem of finding a pair of numbers that sum to a target has already been addressed by Pair Sum - Sorted. However, we can only use that algorithm on a sorted array. So, the first thing we should do is sort the input. Consider the following example:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-01-02-1-A36R4A4P.svg" alt="Diagram 1" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 1</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# Now, starting at the first element, -2 (i.e., &#x27;a&#x27;), we&#x27;ll use the pair_sum_sorted method on the rest of the array to find a pair whose sum equals 2 (i.e., &#x27;-a&#x27;):
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-01-02-2-GBLVHF4M.svg" alt="Diagram 2" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 2</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# As you can see, when we called pair_sum_sorted, we did not find a pair with a sum of 2. This indicates that there are no triplets starting with -2 that add up to 0.
#
# So, let&#x27;s increment our main pointer, i, and try again.
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-01-02-3-XR7EOGIZ.svg" alt="Diagram 3" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 3</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# This time, we found one pair that resulted in a valid triplet.
#
# If we continue this process for the rest of the array, we find that [-1, -1, 2] is the only triplet whose sum is 0.
#
# There’s an important difference between the pair_sum_sorted implementation in Pair Sum - Sorted and the one in this problem: for this problem, we don’t stop when we find one pair, we keep going until all target pairs are found.
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: var(--bbg-h3-color, var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Handling duplicate triplets</h3>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# Something we previously glossed over is how to avoid adding duplicate triplets. There are two cases in which this happens. Consider the example below:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-01-02-4-RKMQCNYS.svg" alt="Diagram 4" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 4</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# Case 1: duplicate ‘a’ values
#
# The first instance where duplicates may occur is when seeking pairs for triplets that start with the same ‘a’ value:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-01-02-5-TXGNCZDQ.svg" alt="Diagram 5" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 5</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# Since pair_sum_sorted would look for pairs that sum ‘-a’ in both instances, we’d naturally end up with the same pairs and, hence, the same triplets.
#
# To avoid picking the same &#x27;a&#x27; value, we keep increasing i (where num[i] represents the value &#x27;a&#x27;) until it reaches a different number from the previous one. We do this before we start looking for pairs using the pair_sum_sorted method. This logic works because the array is sorted, meaning equal numbers are next to each other. The code snippet for checking duplicate &#x27;a&#x27; values looks like this:
#
# </div>

# %% [markdown]
# <h4 class="bbg-h4" style="color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Snippet</h4>

# %%
# To prevent duplicate triplets, ensure 'a' is not a repeat of the previous element
# in the sorted array.
if i > 0 and nums[i] == nums[i - 1]:
    continue
# ... Find triplets ...

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# Case 2: duplicate ‘b’ values
#
# As for the second case, consider what happens during pair_sum_sorted when we encounter a similar issue. For a fixed target value (‘-a’), pairs that start with the same number ‘b’ will always be the same:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-01-02-6-Z75F3BAY.svg" alt="Diagram 6" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 6</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# The remedy for this is the same as before: ensure the current ‘b’ value isn’t the same as the previous value.
#
# It’s important to note that we don’t need to explicitly handle duplicate &#x27;c&#x27; values. The adjustments made to avoid duplicate &#x27;a&#x27; and &#x27;b&#x27; values ensure each pair [a, b] is unique. Since &#x27;c&#x27; is determined by the equation c = -(a + b), each unique [a, b] pair will result in a unique &#x27;c&#x27; value. Therefore, by just avoiding duplicates in &#x27;a&#x27; and &#x27;b&#x27;, we automatically avoid duplicates in the [a, b, c] triplets.
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: var(--bbg-h3-color, var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Optimization</h3>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# An interesting observation is that triplets that sum to 0 cannot be formed using positive numbers alone. Therefore, we can stop trying to find triplets once we reach a positive ‘a’ value since this implies that ‘b’ and ‘c’ would also be positive.
#
# Try it yourself
#
# Write your solution to the problem before checking the reference implementation.
#
# Open Code Editor
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Implementation</h2>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# From the above intuition, we know we need to slightly modify the pair_sum_sorted function to avoid duplicate triplets. We also need to pass in a start value to indicate the beginning of the subarray on which we want to perform the pair-sum algorithm. Otherwise, the two-pointer logic remains nearly identical to that of Pair Sum - Sorted.
#
# </div>

# %% [markdown]
# <h4 class="bbg-h4" style="color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Implementation</h4>

# %%
from typing import List

def triplet_sum(nums: List[int]) -> List[List[int]]:
    triplets = []
    nums.sort()
    for i in range(len(nums)):
        # Optimization: triplets consisting of only positive numbers will never sum
        # to 0.
        if nums[i] > 0:
            break
        # To avoid duplicate triplets, skip 'a' if it's the same as the previous
        # number.
        if i > 0 and nums[i] == nums[i - 1]:
            continue
        # Find all pairs that sum to a target of '-a' ('-nums[i]').
        pairs = pair_sum_sorted_all_pairs(nums, i + 1, -nums[i])
        for pair in pairs:
            triplets.append([nums[i]] + pair)
    return triplets

def pair_sum_sorted_all_pairs(nums: List[int], start: int, target: int) -> List[int]:
    pairs = []
    left, right = start, len(nums) - 1
    while left < right:
        sum = nums[left] + nums[right]
        if sum == target:
            pairs.append([nums[left], nums[right]])
            left += 1 # To avoid duplicate '[b, c]' pairs, skip 'b' if it’s the same as the # previous number.
            while left < right and nums[left] == nums[left - 1]:
                left += 1
        elif sum < target:
            left += 1
        else:
            right -= 1
    return pairs

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Complexity Analysis</h2>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# Time complexity: The time complexity of triplet_sum is $\mathcal{O}(n^2)$. Here’s why:
#
# - We first sort the array, which takes $\mathcal{O}(n \log n)$ time.
# - Then, for each of the n elements in the array, we call pair_sum_sorted_all_pairs at most once, which runs in $\mathcal{O}(n)$ time.
# Therefore, the overall time complexity is $\mathcal{O}(\log n) + \mathcal{O}(n^2) = \mathcal{O}(n^2)$.
#
# Space complexity: The space complexity is $\mathcal{O}(n)$ due to the space taken up by Python’s sorting algorithm. It&#x27;s important to note that this complexity does not include the output array triplets because we’re only concerned with the additional space used by the algorithm, not the space needed for the output itself.
#
# If the interviewer asks what the space complexity would be if we included the output array, it would be $\mathcal{O}(n^2)$. This is because the pair_sum_sorted_all_pairs function, in the worst case, can add approximately n pairs to the output. Since this function is called approximately n times, the overall space complexity is $\mathcal{O}(n^2)$.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Test Cases</h2>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# In addition to the examples already covered in this explanation, below are some others to consider when testing your code.
#
# </div>

# %% [markdown]
# <div class="bbg-card" style=" font-family: Inter, ui-sans-serif, system-ui, sans-serif; margin: 16px auto 20px;">
#
# <table class="bbg-table" style="border-collapse: collapse; width: 100%; white-space: normal;">
# <thead><tr><th style="background: rgba(57,255,136,0.12); color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a)); border-bottom: 1px solid #263447; padding: 10px 12px; text-align: left; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace;">Input</th><th style="background: rgba(57,255,136,0.12); color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a)); border-bottom: 1px solid #263447; padding: 10px 12px; text-align: left; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace;">Expected output</th><th style="background: rgba(57,255,136,0.12); color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a)); border-bottom: 1px solid #263447; padding: 10px 12px; text-align: left; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace;">Description</th></tr></thead>
# <tbody><tr><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">nums = []</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">[]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">Tests an empty array.</td></tr><tr><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">nums = [0]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">[]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">Tests a single-element array.</td></tr><tr><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">nums = [1, -1]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">[]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">Tests a two-element array.</td></tr><tr><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">nums = [0, 0, 0]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">[0, 0, 0]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">Tests an array where all three of its values are the same.</td></tr><tr><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">nums = [1, 0, 1]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">[]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">Tests an array with no triplets that sum to 0.</td></tr><tr><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">nums = [0, 0, 1, -1, 1, -1]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">[-1, 0, 1]</td><td style="border-bottom: 1px solid #263447; color: #e5edf7; padding: 10px 12px; vertical-align: top;">Tests an array with duplicate triplets.</td></tr></tbody>
# </table>
#
# </div>
