# %% [markdown]
# Test 1 (dollar): $\mathcal{O}(n)$
#
# Test 2 (double dollar): $$\mathcal{O}(n)$$
#
# Test 3 (escaped paren): $\mathcal{O}(n)$
#
# Test 4 (escaped bracket): $$\mathcal{O}(n)$$
#
# Test 5 (markdown dollar): $\mathcal{O}(n)$
