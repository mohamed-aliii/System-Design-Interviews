# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon { font-size: 22px !important; line-height: 1.8 !important; }
# .jp-RenderedHTMLCommon h2 { font-size: 1.7em !important; border-left: 5px solid #2d6a4f !important; padding: 10px 0 10px 18px !important; margin-top: 40px !important; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%) !important; border-radius: 4px !important; }
# .jp-RenderedHTMLCommon h3 { font-size: 1.35em !important; border-bottom: 2px solid rgba(45,106,79,0.3) !important; padding-bottom: 8px !important; margin-top: 30px !important; color: #2d6a4f !important; }
# .jp-RenderedHTMLCommon h4 { font-size: 1.15em !important; font-style: italic !important; color: #2d6a4f !important; margin-top: 22px !important; }
# </style>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #081c15 0%, #1b4332 50%, #2d6a4f 100%); padding: 40px 45px; border-radius: 16px; margin-bottom: 30px; border: 1px solid rgba(42,157,143,0.15); max-width: 95%; overflow: hidden; box-sizing: border-box;">
#   <div style="font-size: 15px; font-weight: 600; letter-spacing: 3px; text-transform: uppercase; color: #2d6a4f; margin-bottom: 8px;">Chapter 11</div>
#   <div style="font-size: 36px; font-weight: 800; color: #ffffff; margin-bottom: 16px; line-height: 1.2;">Design a Blackjack Game</div>
#   <div style="width: 60px; height: 4px; background: linear-gradient(90deg, #2d6a4f, rgba(42,157,143,0.5)); border-radius: 2px; margin-bottom: 18px;"></div>
#   <div style="font-size: 17px; color: #b0bec5; line-height: 1.6;">Object-Oriented Design Interview Question</div>
#   <div style="margin-top: 20px; font-size: 13px; color: #546e7a;">Source: ByteByteGo — Object-Oriented Design Interview</div>
# </div>

# %% [markdown]
# In this chapter, we will discuss the object-oriented design of the Blackjack game (also called “21”). Blackjack is a popular card game where the goal is to get a hand of cards that adds up to 21, or as close as possible, without going over. The game is a mix of strategy (deciding when to hit or stand) and luck (the cards you get).

# %% [markdown]
# ![Figure 1: Blackjack Game](assets/image-11-1-CWNCCRFY.svg)

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Requirements Gathering</span>
# </div>

# %% [markdown]
# > “Picture yourself at a casino table, ready to play a round of Blackjack. At the start, you and other players place bets, and the dealer distributes two cards to each player. You evaluate your hand, aiming to get as close to 21 as possible without going over, and decide whether to hit or stand. After all players make their moves, the dealer reveals their hand and hits until reaching at least 17, then stands. Let’s design a Blackjack game system that handles all this.”

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Requirements clarification</span>
# </div>

# %% [markdown]
# <div style="border: 1px solid rgba(45,106,79,0.3); border-radius: 8px; margin: 28px 0; overflow: hidden; font-family: system-ui, -apple-system, sans-serif;">
#   <div style="background: rgba(45,106,79,0.08); padding: 10px 20px; border-bottom: 1px solid rgba(45,106,79,0.3); display: flex; align-items: center; gap: 8px;">
#     <span style="font-size: 1.1em;">&#128483;</span>
#     <span style="font-size: 0.85em; font-weight: 700; color: #2d6a4f; text-transform: uppercase; letter-spacing: 1.5px;">Interview Transcript</span>
#   </div>
#   <div style="padding: 24px 20px 24px 28px; position: relative;">
#     <div style="position: absolute; left: 38px; top: 24px; bottom: 24px; width: 2px; background: rgba(45,106,79,0.3);"></div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Should I design the game to support multiple players or just one player competing against the dealer?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">The game should support multiple players.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">What happens after a player takes their turn?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">After each player takes their turn (“hit” or “stand”), the game should check if all players have either stood or busted. When this happens, the game should determine the winner and settle the bets.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Should the dealer follow any specific rules for when to hit or stand?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, the dealer should continue to “hit” until their hand totals at least 17. Once they reach 17 or higher, they must “stand.”</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #2d6a4f; border: 3px solid transparent; box-shadow: 0 0 0 2px #2d6a4f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #2d6a4f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #2d6a4f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">How are bets handled in the game, and how are players paid?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Players place their bets before the initial cards are dealt. Players who win receive a payout equal to their bet (1:1), while players who bust lose their bet.</div>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Requirements</span>
# </div>

# %% [markdown]
# * The game should support multiple players and a dealer.
#
# * Players are dealt two cards at the beginning.
#
# * Players can “hit” (request an additional card) or “stand” (keep their current hand).
#
# * Aces are valued as 1 or 11, optimizing the player’s hand.
#
# * After all players finish, the dealer hits until reaching at least 17, then stands.
#
# * Players who win receive a payout equal to their bet (1:1); players who bust lose their bet.

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Activity Diagram</span>
# </div>

# %% [markdown]
# Understanding the flow is crucial. An activity diagram visually maps out the workflow, capturing each action, decision, and transition.

# %% [markdown]
# ![Figure 2: Activity Diagram of Blackjack Game](assets/image-11-2-TZNTSFYB.svg)

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Identify Core Objects</span>
# </div>

# %% [markdown]
# * **BlackJackGame**: Central entity managing overall flow — dealing cards, tracking actions, determining winners.
#
# * **Player**: Interface with RealPlayer (human, tracks bets/balance) and DealerPlayer (follows fixed rules, no betting).
#
# * **Hand**: Manages the cards and calculates all possible hand values, handling Aces (1 or 11).
#
# * **Deck**: Manages the 52-card deck — shuffling, drawing, and resetting.
#
# * **Card**: Defined by Rank and Suit enums. Rank determines value; Suit provides identity.

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Design Class Diagram</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Card, Rank, and Suit</span>
# </div>

# %% [markdown]
# The Card class is an immutable building block. `getRankValues()` returns a list of integers (Ace returns `[1, 11]`).

# %% [markdown]
# ![Figure 3: Card class and Rank/Suit enums](assets/image-11-3-KIPQRLZL.svg)

# %% [markdown]
# **Design choice**: Enums for Rank and Suit provide type safety and clarity. Ace’s dual value `[1, 11]` is defined upfront rather than adjusted later.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Deck</span>
# </div>

# %% [markdown]
# The Deck class manages a standard 52-card deck with methods for shuffling, drawing, counting remaining cards, and resetting.

# %% [markdown]
# ![Figure 4: Deck class](assets/image-11-4-2QM6TPBO.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Player</span>
# </div>

# %% [markdown]
# The Player interface with RealPlayer (human with bets/balance) and DealerPlayer (house, follows fixed rules).

# %% [markdown]
# ![Figure 5: Player interface with concrete classes](assets/image-11-5-H325QFH6.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Hand</span>
# </div>

# %% [markdown]
# The Hand class manages cards and computes all possible hand values using a `SortedSet<Integer>`. It handles multiple Aces efficiently by precomputing all combinations.

# %% [markdown]
# ![Figure 6: Hand class](assets/image-11-6-YV2GI6S7.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">BlackJackGame</span>
# </div>

# %% [markdown]
# ![Figure 7: BlackJackGame class](assets/image-11-7-B6DWCECP.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Complete Class Diagram</span>
# </div>

# %% [markdown]
# ![Figure 8: Class Diagram of Blackjack](assets/image-11-8-ZZMNPDXT.svg)

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Code - Blackjack</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Card, Rank, and Suit</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Card {
#     public final Rank rank;
#     public final Suit suit;
#
#     public Card(Rank rank, Suit suit) {
#         this.rank = rank;
#         this.suit = suit;
#     }
#
#     public int[] getRankValues() { return rank.getRankValues(); }
# }
#
# public enum Rank {
#     ACE(new int[] {1, 11}),
#     TWO(new int[] {2}), THREE(new int[] {3}), FOUR(new int[] {4}),
#     FIVE(new int[] {5}), SIX(new int[] {6}), SEVEN(new int[] {7}),
#     EIGHT(new int[] {8}), NINE(new int[] {9}), TEN(new int[] {10}),
#     JACK(new int[] {10}), QUEEN(new int[] {10}), KING(new int[] {10});
#
#     private final int[] rankValues;
#     Rank(int[] rankValues) { this.rankValues = rankValues; }
#     public int[] getRankValues() { return this.rankValues; }
# }
#
# public enum Suit { HEARTS, SPADES, CLUBS, DIAMONDS }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Deck</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Deck {
#     int nextCardIndex = 0;
#     List<Card> cards;
#
#     public Deck() { initializeDeck(); }
#
#     private void initializeDeck() {
#         cards = new ArrayList<>();
#         for (Suit suit : Suit.values()) {
#             for (Rank rank : Rank.values()) {
#                 cards.add(new Card(rank, suit));
#             }
#         }
#         nextCardIndex = 0;
#     }
#
#     public void shuffle() {
#         Collections.shuffle(cards, new Random(System.currentTimeMillis()));
#     }
#
#     public Card draw() {
#         if (isEmpty() || nextCardIndex >= cards.size()) {
#             throw new IllegalStateException("No more cards in deck");
#         }
#         Card drawCard = cards.get(nextCardIndex);
#         nextCardIndex++;
#         return drawCard;
#     }
#
#     public int getRemainingCardCount() { return cards.size() - nextCardIndex; }
#     public boolean isEmpty() { return getRemainingCardCount() == 0; }
#     public void reset() { nextCardIndex = 0; }
# }
# ```
#
# </div>

# %% [markdown]
# **Implementation choice**: Instead of removing cards when drawn (O(n)), the deck tracks the next available card using `nextCardIndex` for O(1) draws.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Hand</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Hand {
#     final List<Card> handCards = new ArrayList<>();
#     final SortedSet<Integer> possibleValues = new TreeSet<>();
#
#     public void addCard(Card card) {
#         if (card == null) throw new IllegalArgumentException("Cannot add null card");
#         handCards.add(card);
#         if (possibleValues.isEmpty()) {
#             for (int value : card.getRankValues()) { possibleValues.add(value); }
#         } else {
#             SortedSet<Integer> newPossibleValue = new TreeSet<>();
#             for (int value : possibleValues) {
#                 for (int cardValue : card.getRankValues()) {
#                     newPossibleValue.add(value + cardValue);
#                 }
#             }
#             possibleValues.clear();
#             possibleValues.addAll(newPossibleValue);
#         }
#     }
#
#     public List<Card> getCards() { return Collections.unmodifiableList(handCards); }
#     public SortedSet<Integer> getPossibleValues() {
#         return Collections.unmodifiableSortedSet(possibleValues);
#     }
#     public void clear() { handCards.clear(); possibleValues.clear(); }
#
#     public boolean isBust() {
#         if (possibleValues.isEmpty()) return false;
#         return possibleValues.first() > 21;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# **Data structure choice**: `TreeSet` (SortedSet) maintains sorted hand values with O(log n) insertion and O(1) access to the lowest value for `isBust()`.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Player Interface and Implementations</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public interface Player {
#     void bet(int bet);
#     void loseBet();
#     void returnBet();
#     void payout();
#     boolean isBust();
#     Hand getHand();
#     int getBalance();
#     String getName();
#     int getBet();
# }
#
# public class RealPlayer implements Player {
#     private final String name;
#     private final Hand hand;
#     private int bet;
#     private int balance;
#
#     public RealPlayer(String name, int startBalance) {
#         this.name = name;
#         this.hand = new Hand();
#         this.bet = 0;
#         this.balance = startBalance;
#     }
#
#     @Override public void bet(int bet) {
#         if (bet > balance) throw new IllegalArgumentException("Bet > balance");
#         this.bet = bet;
#         this.balance -= bet;
#     }
#     @Override public void loseBet() { this.bet = 0; }
#     @Override public void returnBet() { this.balance += bet; this.bet = 0; }
#     @Override public void payout() { this.balance += bet * 2; this.bet = 0; }
#     @Override public boolean isBust() { return hand.isBust(); }
#     @Override public Hand getHand() { return hand; }
#     // other getters omitted
# }
#
# public class DealerPlayer implements Player {
#     private final String name = "Dealer";
#     private final Hand hand;
#
#     public DealerPlayer() { this.hand = new Hand(); }
#     // Bet methods are no-ops for the dealer
#     @Override public void payout() { /* Dealer doesn't get payout */ }
#     @Override public boolean isBust() { return hand.isBust(); }
#     @Override public Hand getHand() { return hand; }
#     // other methods omitted
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">BlackJackGame</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class BlackJackGame {
#     private final Deck deck = new Deck();
#     private final List<Player> players = new ArrayList<>();
#     protected final Player dealer = new DealerPlayer();
#     private Player currentPlayer = null;
#     Map<Player, Action> playerTurnStatusMap = new HashMap<>();
#     GamePhase currentPhase = GamePhase.STARTED;
#
#     public BlackJackGame(List<Player> players) {
#         for (Player player : players) {
#             if (player == null) throw new IllegalArgumentException();
#             this.players.add(player);
#             this.playerTurnStatusMap.put(player, null);
#         }
#         this.playerTurnStatusMap.put(dealer, null);
#         deck.shuffle();
#     }
#
#     public void startNewRound() {
#         deck.reset();
#         for (Player player : playerTurnStatusMap.keySet()) { player.getHand().clear(); }
#         dealer.getHand().clear();
#         playerTurnStatusMap.replaceAll((p, v) -> null);
#         currentPlayer = null;
#         currentPhase = GamePhase.STARTED;
#     }
#
#     public void dealInitialCards() {
#         if (!GamePhase.BET_PLACED.equals(currentPhase))
#             throw new IllegalStateException("All players must bet before dealing");
#         for (Player player : players) { player.getHand().addCard(deck.draw()); }
#         dealer.getHand().addCard(deck.draw());
#         for (Player player : players) { player.getHand().addCard(deck.draw()); }
#         dealer.getHand().addCard(deck.draw());
#         currentPhase = GamePhase.INITIAL_CARD_DRAWN;
#     }
#
#     public void hit(Player player) {
#         if (Action.STAND.equals(playerTurnStatusMap.get(player)))
#             throw new IllegalStateException("Player has already stood");
#         if (player.isBust()) throw new IllegalStateException("Player is already bust");
#         player.getHand().addCard(deck.draw());
#         playerTurnStatusMap.put(player, Action.HIT);
#     }
#
#     public void stand(Player player) {
#         if (Action.STAND.equals(playerTurnStatusMap.get(player)))
#             throw new IllegalStateException("Player has already stood");
#         if (player.isBust()) throw new IllegalStateException("Player is already bust");
#         playerTurnStatusMap.put(player, Action.STAND);
#     }
#
#     protected void dealerTurn() {
#         while (dealer.getHand().getPossibleValues().last() < 17) {
#             dealer.getHand().addCard(deck.draw());
#         }
#         playerTurnStatusMap.put(dealer, Action.STAND);
#         checkGameEndCondition();
#     }
#
#     private void checkGameEndCondition() {
#         boolean allDone = players.stream()
#                 .allMatch(p -> Action.STAND.equals(playerTurnStatusMap.get(p)) || p.isBust());
#         if (!allDone) return;
#
#         int dealerValue = dealer.getHand().getPossibleValues().last();
#         boolean dealerBusts = dealer.isBust();
#         for (Player player : players) {
#             if (player.isBust()) { player.loseBet(); }
#             else {
#                 int pv = player.getHand().getPossibleValues().last();
#                 if (dealerBusts || pv > dealerValue) { player.payout(); }
#                 else if (pv == dealerValue) { player.returnBet(); }
#                 else { player.loseBet(); }
#             }
#         }
#         currentPhase = GamePhase.END;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Deep Dive Topic</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(45,106,79,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #2d6a4f;">Decoupling player and dealer decision logic</span>
# </div>

# %% [markdown]
# To make the design more flexible, we introduce a **PlayerDecisionLogic** interface (Strategy Pattern) that shifts decision-making to individual players.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #2d6a4f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #2d6a4f;">Step 1: Define a decision-making interface</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public interface PlayerDecisionLogic {
#     Action decideAction(Hand hand);
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #2d6a4f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #2d6a4f;">Step 2: Tailor decisions for humans and dealers</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class RealPlayerDecisionLogic implements PlayerDecisionLogic {
#     @Override
#     public Action decideAction(Hand hand) {
#         return hand.getPossibleValues().last() < 16 ? Action.HIT : Action.STAND;
#     }
# }
#
# public class DealerDecisionLogic implements PlayerDecisionLogic {
#     @Override
#     public Action decideAction(Hand hand) {
#         return hand.getPossibleValues().last() < 17 ? Action.HIT : Action.STAND;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #2d6a4f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #2d6a4f;">Step 3: Integrate decisions into players</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public interface Player {
#     PlayerDecisionLogic getDecisionLogic();
#     // ... other methods ...
# }
#
# public class RealPlayer implements Player {
#     private final PlayerDecisionLogic decisionLogic = new RealPlayerDecisionLogic();
#     @Override
#     public PlayerDecisionLogic getDecisionLogic() { return decisionLogic; }
# }
#
# public class DealerPlayer implements Player {
#     private final PlayerDecisionLogic decisionLogic = new DealerDecisionLogic();
#     @Override
#     public PlayerDecisionLogic getDecisionLogic() { return decisionLogic; }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #2d6a4f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #2d6a4f;">Step 4: Adjust the game flow</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #2d6a4f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# // In BlackJackGame
# public void playNextTurn() {
#     Player nextPlayer = getNextEligiblePlayer();
#     if (nextPlayer != null) { performPlayerAction(nextPlayer); }
# }
#
# public void performPlayerAction(Player player) {
#     Action action = player.getDecisionLogic().decideAction(player.getHand());
#     if (action == Action.HIT) { hit(player); }
#     else if (action == Action.STAND) { stand(player); }
# }
# ```
#
# </div>

# %% [markdown]
# ![Figure 9: Strategy Pattern for decision logic](assets/image-11-9-BBJVCDSH.svg)

# %% [markdown]
# This is the **Strategy Pattern**: PlayerDecisionLogic sets the contract, concrete implementations define behaviors, and BlackJackGame uses them without handling decisions internally.

# %% [markdown]
# <div style="border-left: 5px solid #2d6a4f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(45,106,79,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Wrap Up</span>
# </div>

# %% [markdown]
# In this chapter, we built a solid Blackjack game from the ground up. Each piece does its job — Card holds the essentials, Deck shuffles and deals, Hand tracks totals, and BlackJackGame runs the show.

# %% [markdown]
# We also decoupled decision-making with PlayerDecisionLogic using the Strategy Pattern, making it easy to swap strategies for players and the dealer without rewrites.

# %% [markdown]
# Congratulations on getting this far! Now give yourself a pat on the back. Good job!
