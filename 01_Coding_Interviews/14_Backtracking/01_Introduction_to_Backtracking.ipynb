# %% [markdown]
# <!-- ByteByteGo inline UI theme: Code Editor / Algorithm -->
# <style>
#   /* Theme-aware notebook UI colors for VS Code, Jupyter, and browser renderers. */
#   :root {
#     --bbg-title-color: var(--vscode-foreground, var(--jp-content-font-color1, CanvasText));
#     --bbg-muted-color: var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b));
#     --bbg-accent-green: var(--vscode-charts-green, var(--jp-success-color1, #16a34a));
#     --bbg-h3-color: var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb));
#     --bbg-h4-color: var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309));
#     --bbg-pill-bg: rgba(100, 116, 139, 0.08);
#     --bbg-pill-border: rgba(100, 116, 139, 0.18);
#   }
#   @media (prefers-color-scheme: dark) {
#     :root {
#       --bbg-title-color: #e5edf7;
#       --bbg-muted-color: #9fb0c4;
#       --bbg-accent-green: #39ff88;
#       --bbg-h3-color: #38bdf8;
#       --bbg-h4-color: #f59e0b;
#       --bbg-pill-bg: rgba(255, 255, 255, 0.06);
#       --bbg-pill-border: rgba(255, 255, 255, 0.10);
#     }
#   }
#   body[data-jp-theme-light="true"],
#   .vscode-light {
#     --bbg-title-color: #1e293b;
#     --bbg-muted-color: #64748b;
#     --bbg-accent-green: #16a34a;
#     --bbg-h3-color: #2563eb;
#     --bbg-h4-color: #b45309;
#     --bbg-pill-bg: rgba(100, 116, 139, 0.08);
#     --bbg-pill-border: rgba(100, 116, 139, 0.18);
#   }
#   body[data-jp-theme-dark="true"],
#   .vscode-dark {
#     --bbg-title-color: #e5edf7;
#     --bbg-muted-color: #9fb0c4;
#     --bbg-accent-green: #39ff88;
#     --bbg-h3-color: #38bdf8;
#     --bbg-h4-color: #f59e0b;
#     --bbg-pill-bg: rgba(255, 255, 255, 0.06);
#     --bbg-pill-border: rgba(255, 255, 255, 0.10);
#   }
#   .bbg-h2 {
#     color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))) !important;
#     border-left-color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))) !important;
#   }
#   .bbg-h3 { color: var(--bbg-h3-color, var(--vscode-textLink-foreground, var(--jp-content-link-color, #2563eb))) !important; }
#   .bbg-h4 { color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))) !important; }
#   .bbg-kicker { color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))) !important; }
#   .bbg-meta { color: var(--bbg-muted-color, var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b))) !important; }
#   .bbg-pill {
#     background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)) !important;
#     border-color: var(--bbg-pill-border, rgba(100, 116, 139, 0.18)) !important;
#   }
#
#
#   .bbg-banner,
#   .bbg-card,
#   .bbg-figure {
#     box-sizing: border-box;
#     width: 96%;
#     margin-left: auto;
#     margin-right: auto;
#   }
#
#   .bbg-card {
#     overflow-x: auto;
#     font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#     font-size: 17px;
#     line-height: 1.8;
#     letter-spacing: 0.01em;
#   }
#
#   .bbg-card table {
#     width: 100%;
#   }
# </style>

# %% [markdown]
# <div class="bbg-banner" style="background: linear-gradient(135deg, rgba(57,255,136,0.16), rgba(56,189,248,0.11)), linear-gradient(135deg, #0f172a, #111827); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); padding: 28px 50px; margin: 8px auto 26px; box-sizing: border-box; width: 96%;">
#   <div class="bbg-kicker" style="color: var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a)); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px; font-weight: 700; letter-spacing: 0.08em; text-transform: uppercase;">Coding Interview Patterns</div>
#   <h1 style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); font-size: 34px; line-height: 1.15; margin: 10px 0 12px;">Introduction to Backtracking</h1>
#   <div class="bbg-meta" style="color: var(--bbg-muted-color, var(--vscode-descriptionForeground, var(--jp-ui-font-color2, #64748b)); display: flex; flex-wrap: wrap; gap: 10px; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px;">
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Track: Coding Interview Patterns</span>
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Chapter: Backtracking</span>
#     <span class="bbg-pill" style="background: var(--bbg-pill-bg, rgba(100, 116, 139, 0.08)); border: 1px solid var(--bbg-pill-border, rgba(100, 116, 139, 0.18)); border-radius: 999px; padding: 5px 10px;">Theme: Code Editor / Algorithm</span>
#   </div>
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Intuition</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Imagine you're stuck at an intersection point in a maze, and you know one of the three routes ahead leads to the exit:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-14-00-1-6342UDQA.svg" alt="Diagram 1" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 1</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# However, you're not sure which route to take. To find the exit, you decide to try each option one by one, starting with option A. As you walk through passage A, you encounter a new intersection containing two more routes, D and E:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-14-00-2-JOTLN2ST.svg" alt="Diagram 2" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 2</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# You try option D, but it leads to a dead end. So, you backtrack to the second intersection point:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-14-00-3-6A5H7SUB.svg" alt="Diagram 3" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 3</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Next, you try option E, but it also leads to a dead end, so you backtrack to the second junction point. After concluding that neither path D nor E works, you backtrack again to the first intersection point:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-14-00-4-MJ4RNKDY.svg" alt="Diagram 4" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 4</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Having determined that path A doesn't lead to the exit, you move on to path B and discover that it leads to the exit:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-14-00-5-TWVZEBKO.svg" alt="Diagram 5" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 5</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# This **Brute Force** process of testing all possible paths and **Backtracking** upon failure is called '**Backtracking**.' State space **Tree** In **Backtracking**, the state space **Tree**, also known as the decision **Tree**, is a conceptual **Tree** constructed by considering every possible decision that can be made at each point in a process. For example, here's how we would represent the state space **Tree** for the maze scenario:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-14-00-6-DE3PGGPI.svg" alt="Diagram 6" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 6</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Here's a simplified explanation of a state space **Tree**:
#
# - Edges: Each edge represents a possible decision, move, or action.
#
# - Root node: The root node represents the initial state or position before any decisions are made.
#
# - Intermediate nodes: Nodes representing partially completed states or intermediate positions.
#
# - Leaf nodes: The leaf nodes represent complete or invalid solutions.
#
# - Path: A path from the root to any leaf node represents a sequence of decisions that lead to a complete or invalid solution.
#
# Drawing out the state space **Tree** for a problem helps to visualize the entire solution space, and all possible decisions. In addition, it's a great way to understand how the algorithm works.
#
# By figuring out how to traverse this **Tree**, we essentially create the **Backtracking** algorithm. **Backtracking** algorithm Traversing the state space **Tree** is typically done using recursive DFS. Let's discuss how it's implemented at a high level.
#
# Termination condition: Define the condition that specifies when a path should end. This condition should define when we've found a valid and/or invalid solution.
#
# Iterate through decisions: Iterate through every possible decision at the current node, which contains the current state of the problem. For each decision:
#
# - Make that decision and update the current state accordingly.
#
# - Recursively explore all paths that branch from this updated state by calling the DFS function on this state.
#
# - Backtrack by undoing the decision we made and reverting the state.
#
# Below is a crude template for **Backtracking**:
#
# </div>

# %% [markdown]
# <h4 class="bbg-h4" style="color: var(--bbg-h4-color, var(--vscode-terminal-ansiYellow, var(--jp-warn-color1, #b45309))); font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Snippet</h4>

# %%
def dfs(state):
    # Termination condition.
    if meets_termination_condition(state):
        process_solution(state)
        return
    # Explore each possible decision that can be made at the current state.
    for decision in possible_decisions(state):
        make_decision(state, decision)
        dfs(state)
        undo_decision(state, decision)  # Backtrack.

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Analyzing **Time Complexity** Analyzing the **Time Complexity** of **Backtracking** algorithms involves understanding the branching factor and the depth of the state space **Tree**:
#
# - Branching factor: The number of children each node has. It typically represents the maximum number of decisions that can be made for a given state.
#
# - Depth: The length of the deepest path in the state space **Tree**. It corresponds to the number of decisions or steps required to reach a complete solution.
#
# The **Time Complexity** is often estimated as $\mathcal{O}(b\cdot d)$, where b denotes the branching factor and d denotes the depth. This is because in the **Worst Case**, every node at each level of the **Tree** needs to be explored during a typical **Backtracking** algorithm.
#
# When to use **Backtracking** **Backtracking** is useful when we need to explore all possible solutions to a problem. For example, if we need to find all possible ways to arrange items, or generate all possible subsets, permutations, or combinations, **Backtracking** can help to identify every possible solution.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Real-world Example</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# AI algorithms for games: **Backtracking** is used in AI algorithms for games like chess and Go to explore possible moves and strategies. The programs examine each potential move, simulate the game's progression, and evaluate the outcome. If a move leads to an unfavorable position, the program will backtrack to the previous move and try alternative options, systematically exploring the game **Tree** until it finds the **Optimal** strategy.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: var(--bbg-title-color, var(--vscode-foreground, var(--jp-content-font-color1, CanvasText))); border-left: 5px solid var(--bbg-accent-green, var(--vscode-charts-green, var(--jp-success-color1, #16a34a))); font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Chapter Outline</h2>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-14-00-7-53LCGQ5R.svg" alt="Diagram 7" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 7</figcaption>
# </figure>
