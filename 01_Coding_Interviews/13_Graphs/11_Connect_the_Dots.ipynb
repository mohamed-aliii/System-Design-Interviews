# %% [markdown]
# <!-- ByteByteGo inline UI theme: Code Editor / Algorithm -->
# <style>
#   /* Light mode overrides for subtitles - forced legibility without changing HTML source */
#   @media (prefers-color-scheme: light) {
#     .bbg-h2 { color: #1e293b !important; border-left-color: #16a34a !important; }
#     .bbg-h3 { color: #0284c7 !important; }
#     .bbg-h4 { color: #d97706 !important; }
#   }
#   body[data-jp-theme-light="true"] .bbg-h2,
#   .vscode-light .bbg-h2 {
#     color: #1e293b !important;
#     border-left-color: #16a34a !important;
#   }
#   body[data-jp-theme-light="true"] .bbg-h3,
#   .vscode-light .bbg-h3 {
#     color: #0284c7 !important;
#   }
#   body[data-jp-theme-light="true"] .bbg-h4,
#   .vscode-light .bbg-h4 {
#     color: #d97706 !important;
#   }
#
#
#   .bbg-banner,
#   .bbg-card,
#   .bbg-figure {
#     box-sizing: border-box;
#     width: 96%;
#     margin-left: auto;
#     margin-right: auto;
#   }
#
#   .bbg-card {
#     overflow-x: auto;
#     font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;
#     font-size: 17px;
#     line-height: 1.8;
#     letter-spacing: 0.01em;
#   }
#
#   .bbg-card table {
#     width: 100%;
#   }
# </style>

# %% [markdown]
# <div class="bbg-banner" style="background: linear-gradient(135deg, rgba(57,255,136,0.16), rgba(56,189,248,0.11)), linear-gradient(135deg, #0f172a, #111827); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); padding: 28px 50px; margin: 8px auto 26px; box-sizing: border-box; width: 96%;">
#   <div class="bbg-kicker" style="color: #39ff88; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px; font-weight: 700; letter-spacing: 0.08em; text-transform: uppercase;">Coding Interview Patterns</div>
#   <h1 style="color: #e5edf7; font-size: 34px; line-height: 1.15; margin: 10px 0 12px;">Connect the Dots</h1>
#   <div class="bbg-meta" style="color: #9fb0c4; display: flex; flex-wrap: wrap; gap: 10px; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 13px;">
#     <span class="bbg-pill" style="background: rgba(255,255,255,0.06); border: 1px solid rgba(255,255,255,0.10); border-radius: 999px; padding: 5px 10px;">Track: Coding Interview Patterns</span>
#     <span class="bbg-pill" style="background: rgba(255,255,255,0.06); border: 1px solid rgba(255,255,255,0.10); border-radius: 999px; padding: 5px 10px;">Chapter: Graphs</span>
#     <span class="bbg-pill" style="background: rgba(255,255,255,0.06); border: 1px solid rgba(255,255,255,0.10); border-radius: 999px; padding: 5px 10px;">Theme: Code Editor / Algorithm</span>
#   </div>
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Problem</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Given a set of points on a plane, determine the minimum cost to connect all these points. The cost of connecting two points is equal to the Manhattan distance between them, which is calculated as |x1 - x2| + |y1 - y2| for two points (x1, y1) and (x2, y2).
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: #38bdf8; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Example:</h3>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/connect-the-dots-54G3HZID.svg" alt="Diagram 1" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 1</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# **Input:** `points = [[1, 1], [2, 6], [3, 2], [4, 3], [7, 1]]`
#
# **Output:** `15`
#
#
# </div>

# %% [markdown]
# <h3 class="bbg-h3" style="color: #38bdf8; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 22px 0 10px;">Constraints:</h3>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# - There will be at least 2 points on the plane.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Intuition</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Let's treat this problem as a **Graph** problem, imagining each point as a node, and the cost of connecting any two points as the weight of an edge between those nodes. The goal is to connect all nodes (points) in such a way that the total cost is minimized.
#
# This is essentially the minimum spanning **Tree** (MST) problem: The MST of a weighted **Graph** is a way to connect all points in the **Graph**, ensuring each point is reachable from any other point while minimizing the total weight of the connections. There are two main algorithms that are used to find the MST of a **Graph**:
#
# - Kruskal's algorithm
#
# - Prim's algorithm
#
# In this explanation, we'll break down Kruskal's algorithm since it uses a data structure we've already discussed in this chapter: Union-Find. Kruskal's algorithm Kruskal's algorithm is a **Greedy** method for finding the MST.
#
# It essentially builds the MST by connecting nodes with the lowest-weighted edges first while skipping any edges that could cause a cycle. To do this, we first need to identify all the possible edges and sort them by their Manhattan distance:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-13-10-1-7FC2A62P.svg" alt="Diagram 2" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 2</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Now, let's implement Kruskal's algorithm. Start by including the lowest weighted edge in the MST, which is the edge from (3, 2) to (4, 3):
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-13-10-2-6R7WDGR2.svg" alt="Diagram 3" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 3</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Next, add the next lowest weighted edge, which is the edge from (1, 1) to (3, 2):
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-13-10-3-XTWLZA2R.svg" alt="Diagram 4" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 4</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Notice that adding the next edge from (1, 1) to (4, 3) will cause a cycle. Edges that cause cycles are avoided in an MST because doing so implies we're connecting two points that are already connected. So, let's skip this edge:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-13-10-4-FPX52OEA.svg" alt="Diagram 5" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 5</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Continuing this process until all points are connected gives us the MST:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-13-10-5-GNJMTXIG.svg" alt="Diagram 6" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 6</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# We'll know that all points are connected once we've added a total of n - 1 edges to the MST, because this is the least number of edges needed to connect n points without any cycles. To attain the cost of this MST, we just need to keep track of the Manhattan cost of each edge we add to the MST.
#
# Now that we have a strategy to find the MST of a set of points, we just need a way to determine when connecting two points leads to a cycle. Avoiding cycles A cycle is formed when we add an edge to nodes that are already connected in some way.
#
# Consider the following set of points, where the group of points to the left are connected, and the group of points to the right are connected:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-13-10-6-MLLQKBLY.svg" alt="Diagram 7" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 7</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Connecting any two points in the same group causes a cycle, and connecting two points from two separate groups will result in both groups merging into one:
#
# </div>

# %% [markdown]
# <figure class="bbg-figure" style="background: #ffffff; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 14px auto 20px; padding: 14px; box-sizing: border-box; width: 96%;">
#   <img src="assets/image-13-10-7-WGQVNMYI.svg" alt="Diagram 8" style="display: block; height: auto; margin: 0 auto; max-width: 100%; width: 100%;">
#   <figcaption class="bbg-caption" style="color: #475569; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; font-size: 12px; margin-top: 8px; text-align: center;">Diagram 8</figcaption>
# </figure>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# What would be useful here is a way to determine if two points belong to the same group, and a way to merge two groups together. The Union-Find data structure is perfect for this. We can use the union function to connect two points together.
#
# - If the two points belong to two separate groups, union should merge those groups and return true.
#
# - Otherwise, if they belong to the same group, union should return false.
#
# This way, we can use this boolean return value as a way to determine if attempting to connect two points causes a cycle. If you're not familiar with Union-Find, study the solution to the Merging Communities problem.
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Try it yourself</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# Write your solution to the problem before checking the reference implementation. Open Code Editor
#
# </div>

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Implementation</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# In this implementation, we'll identify each point using their index in the points array. This means that for n points, each point is represented by an index from 0 to n - 1. By doing this, we can set up a Union-Find data structure with a capacity of n so that there are n groups initially, with each group containing one of the n points.
#
# </div>

# %% [markdown]
# <h4 class="bbg-h4" style="color: #f59e0b; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Implementation</h4>

# %%
from typing import List

def connect_the_dots(points: List[List[int]]) -> int:
    n = len(points)
    # Create and populate a list of all possible edges.
    edges = []
    for i in range(n):
        for j in range(i + 1, n):
            # Manhattan distance.
            cost = (abs(points[i][0] - points[j][0]) +
                    abs(points[i][1] - points[j][1]))
            edges.append((cost, i, j))
    # Sort the edges by their cost in ascending order.
    edges.sort()
    uf = UnionFind(n)
    total_cost = edges_added = 0
    # Use Kruskal's algorithm to create the MST and identify its minimum cost.
    for cost, p1, p2 in edges:
        # If the points are not already connected (i.e. their representatives are
        # not the same), connect them, and add the cost to the total cost.
        if uf.union(p1, p2):
            total_cost += cost
            edges_added += 1
            # If n - 1 edges have been added to the MST, the MST is complete.
            if edges_added == n - 1:
                return total_cost

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# The Union-Find data structure remains the same as the implementation provided in Merging Communities, with a slight modification made to the union function, adding a boolean return value to it.
#
# </div>

# %% [markdown]
# <h4 class="bbg-h4" style="color: #f59e0b; font-family: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace; letter-spacing: 0; margin: 18px 0 8px;">Python Implementation</h4>

# %%
class UnionFind:
    def __init__(self, size):
        self.parent = [i for i in range(size)]
        self.size = [1] * size

    def union(self, x, y) -> bool:
        rep_x, rep_y = self.find(x), self.find(y)
        if rep_x != rep_y:
            if self.size[rep_x] > self.size[rep_y]:
                self.parent[rep_y] = rep_x
                self.size[rep_x] += self.size[rep_y]
            else:
                self.parent[rep_x] = rep_y
                self.size[rep_y] += self.size[rep_x]
            # Return True if both groups were merged.
            return True
        # Return False if the points belong to the same group.
        return False

    def find(self, x) -> int:
        if x == self.parent[x]:
            return x
        self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

# %% [markdown]
# <h2 class="bbg-h2" style="color: #e5edf7; border-left: 5px solid #39ff88; font-family: Inter, ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; letter-spacing: 0; margin: 28px 0 12px; padding-left: 12px;">Complexity Analysis</h2>

# %% [markdown]
# <div class="bbg-card" style="background: linear-gradient(180deg, #111827, #172033); color: #e5edf7; border: 1px solid #263447; border-radius: 12px; box-shadow: 0 18px 45px rgba(0, 0, 0, 0.28); margin: 12px auto 18px; padding: 18px 40px; box-sizing: border-box; width: 96%;">
#
# **Time Complexity**: The **Time Complexity** of the connect_the_dots is $\mathcal{O}(n^2\log(n))$, where n denotes the length of the points array, and $n^2$ is the number of edges in the edges array, since we consider all possible pairs of points to form edges. Here's why:
#
# - Sorting $n^2$ edges takes $\mathcal{O}(n^2\log(n^2))$ time, which can be simplified to $\mathcal{O}(n^2\log(n))$.
#
# - We perform up to one union operation for each edge, with each union taking amortized $\mathcal{O}(1)$ time, resulting in the union operations contributing amortized $\mathcal{O}(n^2)$ time.
#
# Therefore, the overall **Time Complexity** is $\mathcal{O}(n^2+n^2\log(n))$=$\mathcal{O}(n^2\log(n))$. **Space Complexity**: The **Space Complexity** is $\mathcal{O}(n^2)$ due to the space taken up by the edges list. In addition, the UnionFind data structure takes up $\mathcal{O}(n)$ space.
#
# </div>
