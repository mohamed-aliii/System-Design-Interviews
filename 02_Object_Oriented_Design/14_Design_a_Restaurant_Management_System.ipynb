# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon { font-size: 22px !important; line-height: 1.8 !important; }
# .jp-RenderedHTMLCommon h2 { font-size: 1.7em !important; border-left: 5px solid #d4a373 !important; padding: 10px 0 10px 18px !important; margin-top: 40px !important; background: linear-gradient(90deg, rgba(212,163,115,0.08) 0%, transparent 60%) !important; border-radius: 4px !important; }
# .jp-RenderedHTMLCommon h3 { font-size: 1.35em !important; border-bottom: 2px solid rgba(212,163,115,0.3) !important; padding-bottom: 8px !important; margin-top: 30px !important; color: #d4a373 !important; }
# .jp-RenderedHTMLCommon h4 { font-size: 1.15em !important; font-style: italic !important; color: #d4a373 !important; margin-top: 22px !important; }
# </style>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #3d2b1f 0%, #6b4226 50%, #d4a373 100%); padding: 40px 45px; border-radius: 16px; margin-bottom: 30px; border: 1px solid rgba(42,157,143,0.15); max-width: 95%; overflow: hidden; box-sizing: border-box;">
#   <div style="font-size: 15px; font-weight: 600; letter-spacing: 3px; text-transform: uppercase; color: #fefae0; margin-bottom: 8px;">Chapter 14</div>
#   <div style="font-size: 36px; font-weight: 800; color: #ffffff; margin-bottom: 16px; line-height: 1.2;">Design a Restaurant Management System</div>
#   <div style="width: 60px; height: 4px; background: linear-gradient(90deg, #d4a373, #fefae0); border-radius: 2px; margin-bottom: 18px;"></div>
#   <div style="font-size: 17px; color: #b0bec5; line-height: 1.6;">Object-Oriented Design Interview Question</div>
#   <div style="margin-top: 20px; font-size: 13px; color: #546e7a;">Source: ByteByteGo — Object-Oriented Design Interview</div>
# </div>

# %% [markdown]
# In this chapter, we will explore the design of a Restaurant Management System. The goal is to create classes that represent essential components — menus, reservations, and tables — supporting functions like booking reservations, managing orders, and assigning tables.

# %% [markdown]
# ![Figure 1: Restaurant Reservation](assets/image-14-1-MKXZVGKS.svg)

# %% [markdown]
# <div style="border-left: 5px solid #d4a373; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(212,163,115,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Requirements Gathering</span>
# </div>

# %% [markdown]
# > “Picture yourself planning a dinner outing on a Friday night. You call the restaurant to reserve a table, check available times, and secure a spot. When you arrive, the staff assigns your party to the reserved table, takes your order, and later presents the bill. Let’s design a Restaurant Management System that manages all of this.”

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Requirements clarification</span>
# </div>

# %% [markdown]
# <div style="border: 1px solid rgba(212,163,115,0.3); border-radius: 8px; margin: 28px 0; overflow: hidden; font-family: system-ui, -apple-system, sans-serif;">
#   <div style="background: rgba(212,163,115,0.08); padding: 10px 20px; border-bottom: 1px solid rgba(212,163,115,0.3); display: flex; align-items: center; gap: 8px;">
#     <span style="font-size: 1.1em;">&#128483;</span>
#     <span style="font-size: 0.85em; font-weight: 700; color: #d4a373; text-transform: uppercase; letter-spacing: 1.5px;">Interview Transcript</span>
#   </div>
#   <div style="padding: 24px 20px 24px 28px; position: relative;">
#     <div style="position: absolute; left: 38px; top: 24px; bottom: 24px; width: 2px; background: rgba(212,163,115,0.3);"></div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Let’s set the scope. I assume the system manages reservations, menu, order tracking, and payments. I’ll focus on reservations and order management. Does that work?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">That’s a reasonable starting point.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Does the system allow customers to make and manage their reservations?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, customers can book tables for a future date and time based on availability.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">How does the system determine if a table is available?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">It checks for a table that fits the party size and is free at the requested time. Each reservation reserves a table for exactly one hour.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Can customers cancel a reservation?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, customers can cancel reservations.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">When a party with a reservation arrives, do they automatically get their reserved table?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes. They arrive with their name, and the system uses it to find their reservation.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">What about walk-in parties without prior reservation?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">The system should assign walk-in parties to tables based on current availability and party size.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Can orders be altered or removed after they’re placed?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, you can remove items or adjust their quantities.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Does the system track order status?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, it keeps track of their progress.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #d4a373; border: 3px solid transparent; box-shadow: 0 0 0 2px #d4a373; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #d4a373; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #d4a373; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Are there rules for splitting the bill?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">For now, just present a single total bill amount.</div>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Requirements</span>
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #d4a373; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #d4a373;">Reservations</span>
# </div>

# %% [markdown]
# * Customers can book tables for a future date/time based on availability.
#
# * Each reservation reserves a table for exactly one hour.
#
# * The system checks for no overlapping bookings.
#
# * Customers can cancel reservations.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #d4a373; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #d4a373;">Walk-in seating</span>
# </div>

# %% [markdown]
# * The system assigns walk-in parties to tables based on current availability and party size.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #d4a373; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #d4a373;">Order management</span>
# </div>

# %% [markdown]
# * Orders can be altered or removed after placement.
#
# * The system tracks order progress.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #d4a373; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #d4a373;">Billing</span>
# </div>

# %% [markdown]
# * The system presents a single total bill amount at checkout.

# %% [markdown]
# <div style="border-left: 5px solid #d4a373; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(212,163,115,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Identify Core Objects</span>
# </div>

# %% [markdown]
# * **Menu**: Stores available menu items.
#
# * **MenuItem**: Individual menu item with name, description, price, and category.
#
# * **Layout**: Physical arrangement of tables, organized for efficient assignment.
#
# * **Table**: Individual table with capacity, reservations, and active orders.
#
# * **Reservation**: Party name, size, time, and assigned table.
#
# * **ReservationManager**: Manages creation, lookup, and cancellation of reservations.
#
# * **Restaurant**: Facade providing a central interface for all operations.

# %% [markdown]
# <div style="border-left: 5px solid #d4a373; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(212,163,115,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Design Class Diagram</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Menu</span>
# </div>

# %% [markdown]
# ![Figure 2: Menu class](assets/image-14-2-FNRKUKHH.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">MenuItem and Category</span>
# </div>

# %% [markdown]
# ![Figure 3: MenuItem class and Category enum](assets/image-14-3-7HSKQ37H.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Table</span>
# </div>

# %% [markdown]
# ![Figure 4: Table class](assets/image-14-4-XJZ7R4LH.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Layout</span>
# </div>

# %% [markdown]
# ![Figure 5: Layout class](assets/image-14-5-2TM3C43X.svg)

# %% [markdown]
# **Design choice**: Layout isolates table organization to optimize assignment efficiency, separated from menu and order logic.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">OrderItem and Status</span>
# </div>

# %% [markdown]
# ![Figure 6: OrderItem class and Status enum](assets/image-14-6-AENV5YNW.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">ReservationManager</span>
# </div>

# %% [markdown]
# ![Figure 7: ReservationManager class](assets/image-14-7-HWI7YEFO.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Reservation</span>
# </div>

# %% [markdown]
# ![Figure 8: Reservation class](assets/image-14-8-7GFSUO7G.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Restaurant</span>
# </div>

# %% [markdown]
# ![Figure 9: Restaurant class](assets/image-14-9-QO7CCEFQ.svg)

# %% [markdown]
# **Design choice**: Facade pattern — delegates to ReservationManager, Layout, Menu, and Table.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Complete Class Diagram</span>
# </div>

# %% [markdown]
# ![Figure 10: Class Diagram of Restaurant Management System](assets/image-14-10-NRTZ3GM7.svg)

# %% [markdown]
# <div style="border-left: 5px solid #d4a373; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(212,163,115,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Code - Restaurant Management System</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Menu</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Menu {
#     private final Map<String, MenuItem> menuItems = new HashMap<>();
#
#     public void addItem(MenuItem item) { menuItems.put(item.getName(), item); }
#     public MenuItem getItem(String name) { return menuItems.get(name); }
#     public Map<String, MenuItem> getMenuItems() {
#         return Collections.unmodifiableMap(menuItems);
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">MenuItem</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class MenuItem {
#     private final String name;
#     private final String description;
#     private final BigDecimal price;
#     private final Category category;
#
#     public MenuItem(String name, String description, BigDecimal price, Category category) {
#         this.name = name;
#         this.description = description;
#         this.price = price;
#         this.category = category;
#     }
#
#     public enum Category { MAIN, APPETIZER, DESSERT }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Table</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Table {
#     private final int tableId;
#     private final int capacity;
#     private final Map<LocalDateTime, Reservation> reservations = new HashMap<>();
#     private final Map<MenuItem, List<OrderItem>> orderedItems = new HashMap<>();
#
#     public Table(int tableId, int capacity) {
#         this.tableId = tableId;
#         this.capacity = capacity;
#     }
#
#     public BigDecimal calculateBillAmount() {
#         return orderedItems.values().stream()
#                 .flatMap(List::stream)
#                 .map(OrderItem::getItem)
#                 .map(MenuItem::getPrice)
#                 .reduce(BigDecimal.ZERO, BigDecimal::add);
#     }
#
#     public void addOrder(MenuItem item, int quantity) {
#         for (int i = 0; i < quantity; i++) { addOrder(item); }
#     }
#
#     public void addOrder(MenuItem item) {
#         orderedItems.computeIfAbsent(item, k -> new ArrayList<>())
#                     .add(new OrderItem(item));
#     }
#
#     public void removeOrder(MenuItem item) {
#         List<OrderItem> items = orderedItems.get(item);
#         if (items != null) {
#             items.remove(0);
#             if (items.isEmpty()) orderedItems.remove(item);
#         }
#     }
#
#     public boolean isAvailableAt(LocalDateTime time) {
#         return !reservations.containsKey(time);
#     }
#
#     public void addReservation(Reservation r) { reservations.put(r.getTime(), r); }
#     public void removeReservation(LocalDateTime t) { reservations.remove(t); }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Layout</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Layout {
#     private final Map<Integer, Table> tablesById = new HashMap<>();
#     private final SortedMap<Integer, Set<Table>> tablesByCapacity = new TreeMap<>();
#
#     public Layout(List<Integer> tableCapacities) {
#         for (int i = 0; i < tableCapacities.size(); i++) {
#             int capacity = tableCapacities.get(i);
#             Table table = new Table(i, capacity);
#             tablesById.put(i, table);
#             tablesByCapacity.computeIfAbsent(capacity, k -> new HashSet<>()).add(table);
#         }
#     }
#
#     public Table findAvailableTable(int partySize, LocalDateTime reservationTime) {
#         for (Set<Table> tables : tablesByCapacity.tailMap(partySize).values()) {
#             for (Table table : tables) {
#                 if (table.isAvailableAt(reservationTime)) return table;
#             }
#         }
#         return null;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# **Implementation choice**: `SortedMap` (TreeMap) for `tablesByCapacity` enables efficient range searches via `tailMap(partySize)` to find the smallest fitting table.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">OrderItem</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class OrderItem {
#     private final MenuItem item;
#     private Status status = Status.PENDING;
#
#     public OrderItem(MenuItem item) { this.item = item; }
#
#     public void sendToKitchen() {
#         if (status == Status.PENDING) status = Status.SENT_TO_KITCHEN;
#     }
#     public void deliverToCustomer() {
#         if (status == Status.SENT_TO_KITCHEN) status = Status.DELIVERED;
#     }
#     public void cancel() {
#         if (status == Status.PENDING || status == Status.SENT_TO_KITCHEN)
#             status = Status.CANCELED;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">ReservationManager</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class ReservationManager {
#     private final Layout layout;
#     private final Set<Reservation> reservations = new HashSet<>();
#
#     public ReservationManager(Layout layout) { this.layout = layout; }
#
#     public LocalDateTime[] findAvailableTimeSlots(
#             LocalDateTime rangeStart, LocalDateTime rangeEnd, int partySize) {
#         LocalDateTime current = rangeStart;
#         List<LocalDateTime> possible = new ArrayList<>();
#         while (!current.isAfter(rangeEnd)) {
#             if (layout.findAvailableTable(partySize, current) != null)
#                 possible.add(current);
#             current = current.plusHours(1);
#         }
#         return possible.toArray(new LocalDateTime[0]);
#     }
#
#     public Reservation createReservation(
#             String partyName, int partySize, LocalDateTime desiredTime) {
#         desiredTime = desiredTime.truncatedTo(ChronoUnit.HOURS);
#         Table table = layout.findAvailableTable(partySize, desiredTime);
#         Reservation reservation = new Reservation(partyName, partySize, desiredTime, table);
#         table.addReservation(reservation);
#         reservations.add(reservation);
#         return reservation;
#     }
#
#     public void removeReservation(
#             String partyName, int partySize, LocalDateTime reservationTime) {
#         for (Reservation r : new HashSet<>(reservations)) {
#             if (r.getTime().equals(reservationTime)
#                     && r.getPartySize() == partySize
#                     && r.getPartyName().equals(partyName)) {
#                 r.getAssignedTable().removeReservation(reservationTime);
#                 reservations.remove(r);
#                 return;
#             }
#         }
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(212,163,115,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #d4a373;">Restaurant (Facade)</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Restaurant {
#     private final String name;
#     private final Menu menu;
#     private final Layout layout;
#     private final ReservationManager reservationManager;
#
#     public Restaurant(String name, Menu menu, Layout layout) {
#         this.name = name;
#         this.menu = menu;
#         this.layout = layout;
#         this.reservationManager = new ReservationManager(layout);
#     }
#
#     public LocalDateTime[] findAvailableTimeSlots(
#             LocalDateTime rangeStart, LocalDateTime rangeEnd, int partySize) {
#         return reservationManager.findAvailableTimeSlots(rangeStart, rangeEnd, partySize);
#     }
#
#     public Reservation createScheduledReservation(
#             String partyName, int partySize, LocalDateTime time) {
#         return reservationManager.createReservation(partyName, partySize, time);
#     }
#
#     public void removeReservation(
#             String partyName, int partySize, LocalDateTime reservationTime) {
#         reservationManager.removeReservation(partyName, partySize, reservationTime);
#     }
#
#     public Reservation createWalkInReservation(String partyName, int partySize) {
#         return reservationManager.createReservation(partyName, partySize, LocalDateTime.now());
#     }
#
#     public void orderItem(Table table, MenuItem item) { table.addOrder(item); }
#     public void cancelItem(Table table, MenuItem item) { table.removeOrder(item); }
#     public BigDecimal calculateTableBill(Table table) { return table.calculateBillAmount(); }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #d4a373; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(212,163,115,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Deep Dive: Order Queue Tracking (Command Pattern)</span>
# </div>

# %% [markdown]
# During peak times, the decentralized order status management in Table lacks a cohesive overview. We introduce a centralized **OrderManager** using the **Command Pattern**.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #d4a373; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #d4a373;">Step 1: Define OrderCommand interface</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public interface OrderCommand {
#     void execute();
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #d4a373; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #d4a373;">Step 2: Implement concrete commands</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class SendToKitchenCommand implements OrderCommand {
#     private final OrderItem orderItem;
#     public SendToKitchenCommand(OrderItem orderItem) { this.orderItem = orderItem; }
#     @Override public void execute() { orderItem.sendToKitchen(); }
# }
#
# public class DeliverCommand implements OrderCommand {
#     private final OrderItem orderItem;
#     public DeliverCommand(OrderItem orderItem) { this.orderItem = orderItem; }
#     @Override public void execute() { orderItem.deliverToCustomer(); }
# }
#
# public class CancelCommand implements OrderCommand {
#     private final OrderItem orderItem;
#     public CancelCommand(OrderItem orderItem) { this.orderItem = orderItem; }
#     @Override public void execute() { orderItem.cancel(); }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #d4a373; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #d4a373;">Step 3: OrderManager (Invoker)</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class OrderManager {
#     private final List<OrderCommand> commandQueue = new ArrayList<>();
#
#     public void addCommand(OrderCommand command) { commandQueue.add(command); }
#
#     public void executeCommands() {
#         for (OrderCommand command : commandQueue) { command.execute(); }
#         commandQueue.clear();
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #d4a373; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #d4a373;">Step 4: Integrate with Restaurant</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #d4a373; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# // Updated Restaurant with OrderManager
# public void orderItem(Table table, MenuItem item) {
#     table.addOrder(item);
#     List<OrderItem> orderItems = table.getOrderedItems().get(item);
#     if (orderItems != null && !orderItems.isEmpty()) {
#         OrderItem lastOrder = orderItems.get(orderItems.size() - 1);
#         orderManager.addCommand(new SendToKitchenCommand(lastOrder));
#         orderManager.executeCommands();
#     }
# }
#
# public void cancelItem(Table table, MenuItem item) {
#     List<OrderItem> orderItems = table.getOrderedItems().get(item);
#     if (orderItems != null && !orderItems.isEmpty()) {
#         OrderItem lastOrder = orderItems.get(orderItems.size() - 1);
#         orderManager.addCommand(new CancelCommand(lastOrder));
#         orderManager.executeCommands();
#         table.removeOrder(item);
#     }
# }
# ```
#
# </div>

# %% [markdown]
# **Command Pattern roles**: OrderCommand = Command, OrderManager = Invoker, OrderItem = Receiver.

# %% [markdown]
# ![Figure 11: Command Pattern](assets/image-14-11-RENAQ5K3.svg)

# %% [markdown]
# <div style="border-left: 5px solid #d4a373; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(212,163,115,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Wrap Up</span>
# </div>

# %% [markdown]
# In this chapter, we designed a Restaurant Management System with clear separation of concerns. Each component — Menu, ReservationManager, Layout, and Table — manages a distinct responsibility.

# %% [markdown]
# In the deep dive, we enhanced order handling with the Command Pattern for centralized queue tracking during peak times.

# %% [markdown]
# Congratulations on getting this far! Now give yourself a pat on the back. Good job!
