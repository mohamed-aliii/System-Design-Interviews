# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon { font-size: 22px !important; line-height: 1.8 !important; }
# .jp-RenderedHTMLCommon h2 { font-size: 1.7em !important; border-left: 5px solid #e63946 !important; padding: 10px 0 10px 18px !important; margin-top: 40px !important; background: linear-gradient(90deg, rgba(230,57,70,0.08) 0%, transparent 60%) !important; border-radius: 4px !important; }
# .jp-RenderedHTMLCommon h3 { font-size: 1.35em !important; border-bottom: 2px solid rgba(230,57,70,0.3) !important; padding-bottom: 8px !important; margin-top: 30px !important; color: #e63946 !important; }
# .jp-RenderedHTMLCommon h4 { font-size: 1.15em !important; font-style: italic !important; color: #e63946 !important; margin-top: 22px !important; }
# </style>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #1d1128 0%, #6b2737 50%, #e63946 100%); padding: 40px 45px; border-radius: 16px; margin-bottom: 30px; border: 1px solid rgba(42,157,143,0.15); max-width: 95%; overflow: hidden; box-sizing: border-box;">
#   <div style="font-size: 15px; font-weight: 600; letter-spacing: 3px; text-transform: uppercase; color: #e63946; margin-bottom: 8px;">Chapter 10</div>
#   <div style="font-size: 36px; font-weight: 800; color: #ffffff; margin-bottom: 16px; line-height: 1.2;">Design a Tic Tac Toe Game</div>
#   <div style="width: 60px; height: 4px; background: linear-gradient(90deg, #e63946, rgba(42,157,143,0.5)); border-radius: 2px; margin-bottom: 18px;"></div>
#   <div style="font-size: 17px; color: #b0bec5; line-height: 1.6;">Object-Oriented Design Interview Question</div>
#   <div style="margin-top: 20px; font-size: 13px; color: #546e7a;">Source: ByteByteGo — Object-Oriented Design Interview</div>
# </div>

# %% [markdown]
# In this chapter, we will explore the object-oriented design of a Tic-Tac-Toe game. We aim to create an interactive platform where two players alternate turns, placing their symbols on a virtual board. We’ll design key components such as the game board, player move tracking, outcome determination, and a score tracker for managing player ratings.

# %% [markdown]
# **How Tic-Tac-Toe Works**: Tic-Tac-Toe is a classic two-player game played on a 3×3 grid. Each player selects a symbol (“X” or “O”) and takes turns placing it in an empty cell. The goal is to align three identical symbols horizontally, vertically, or diagonally. The game concludes with a win or a draw if all nine cells are filled without a winner.

# %% [markdown]
# ![Figure 1: Tic-Tac-Toe](assets/image-10-1-6GMZSEBF.png)

# %% [markdown]
# <div style="border-left: 5px solid #e63946; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(230,57,70,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Requirements Gathering</span>
# </div>

# %% [markdown]
# > “Imagine you and a friend are sitting down for a quick game of Tic-Tac-Toe. You each choose a symbol and take turns placing it on a board. After each move, the game checks if someone has won or if the board is full, signaling a draw. Behind the scenes, the game tracks your moves, updates a scoreboard to reflect wins, and maintains player rankings. Let’s design a Tic-Tac-Toe game system that handles all this.”

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Requirements clarification</span>
# </div>

# %% [markdown]
# <div style="border: 1px solid rgba(230,57,70,0.3); border-radius: 8px; margin: 28px 0; overflow: hidden; font-family: system-ui, -apple-system, sans-serif;">
#   <div style="background: rgba(230,57,70,0.08); padding: 10px 20px; border-bottom: 1px solid rgba(230,57,70,0.3); display: flex; align-items: center; gap: 8px;">
#     <span style="font-size: 1.1em;">&#128483;</span>
#     <span style="font-size: 0.85em; font-weight: 700; color: #e63946; text-transform: uppercase; letter-spacing: 1.5px;">Interview Transcript</span>
#   </div>
#   <div style="padding: 24px 20px 24px 28px; position: relative;">
#     <div style="position: absolute; left: 38px; top: 24px; bottom: 24px; width: 2px; background: rgba(230,57,70,0.3);"></div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e63946; border: 3px solid transparent; box-shadow: 0 0 0 2px #e63946; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e63946; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e63946; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Does the game support different board sizes?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">No, let’s stick to the standard 3×3 board for simplicity.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e63946; border: 3px solid transparent; box-shadow: 0 0 0 2px #e63946; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e63946; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e63946; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">How should the game handle outcomes like wins, losses, and draws?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">The system must detect winning patterns and notify players of the result: win, draw, or ongoing.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e63946; border: 3px solid transparent; box-shadow: 0 0 0 2px #e63946; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e63946; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e63946; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Should the game track player ratings?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, the game should maintain a score tracker that updates player ratings based on game outcomes.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e63946; border: 3px solid transparent; box-shadow: 0 0 0 2px #e63946; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e63946; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e63946; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">How does the game handle invalid moves?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">If a player attempts a move in an occupied or invalid position, notify them and prompt for a new move.</div>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Requirements</span>
# </div>

# %% [markdown]
# * The game is played on a 3×3 board.
#
# * The system determines the game’s status: a win, a draw, or in progress.
#
# * A score tracker records player performance and supports rankings.
#
# * Invalid moves are rejected with feedback to the player.

# %% [markdown]
# Non-functional requirements:

# %% [markdown]
# * Intuitive UI with clear feedback for invalid moves and outcomes.
#
# * Support for future enhancements (different board sizes, game modes) without major changes.

# %% [markdown]
# <div style="border-left: 5px solid #e63946; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(230,57,70,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Identify Core Objects</span>
# </div>

# %% [markdown]
# * **Board**: Models the 3×3 game grid. Handles updates, win-checking, and full-board detection.
#
# * **Player**: Represents an individual player with a name and symbol.
#
# * **Game**: Central entity coordinating turn-taking, move validation, and game status tracking.
#
# * **ScoreTracker**: Tracks player ratings across games using a centralized scoreboard.

# %% [markdown]
# **Design choice**: The Game class delegates the Board to manage the grid and ScoreTracker to handle ratings, keeping it manageable.

# %% [markdown]
# <div style="border-left: 5px solid #e63946; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(230,57,70,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Design Class Diagram</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Game</span>
# </div>

# %% [markdown]
# The Game class is the central coordinator. It manages gameplay flow, initializing components, handling turns, and determining the outcome.

# %% [markdown]
# ![Figure 2: Game class](assets/image-10-2-KKT34U5Z.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Board</span>
# </div>

# %% [markdown]
# The Board class represents the 3×3 game grid modeled as a 2D array of Player objects. It enforces game rules at the board level and determines if a player has won.

# %% [markdown]
# ![Figure 3: Board class](assets/image-10-3-P2D3SDD5.svg)

# %% [markdown]
# **Design choice**: Win-checking logic is in the Board class (not Game), aligning with the Single Responsibility Principle.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">ScoreTracker</span>
# </div>

# %% [markdown]
# The ScoreTracker class monitors player performance across multiple games using a `HashMap<Player, Integer>` for win counts.

# %% [markdown]
# ![Figure 4: ScoreTracker class](assets/image-10-4-NLOLJLB2.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Move</span>
# </div>

# %% [markdown]
# The Move class captures a player’s move — the row and column indices plus a reference to the player.

# %% [markdown]
# ![Figure 5: Move class](assets/image-10-5-VOHWWKQC.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Player</span>
# </div>

# %% [markdown]
# The Player class encapsulates a player’s name and assigned symbol.

# %% [markdown]
# ![Figure 6: Player class](assets/image-10-6-MYLMDGQB.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Complete Class Diagram</span>
# </div>

# %% [markdown]
# ![Figure 7: Class Diagram of Tic-Tac-Toe](assets/image-10-7-FD45RBK2.svg)

# %% [markdown]
# <div style="border-left: 5px solid #e63946; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(230,57,70,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Code - Tic-Tac-Toe Game</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Game</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e63946; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Game {
#     private final Board board;
#     private final ScoreTracker scoreTracker;
#     private Player[] players;
#     private int currentPlayerIndex;
#
#     public Game(Player playerX, Player playerY) {
#         board = new Board();
#         scoreTracker = new ScoreTracker();
#         startNewGame(playerX, playerY);
#     }
#
#     public void startNewGame(Player playerX, Player playerY) {
#         board.reset();
#         players = new Player[] {playerX, playerY};
#         currentPlayerIndex = 0;
#     }
#
#     public void makeMove(int colIndex, int rowIndex, Player player) {
#         if (getGameStatus().equals(GameCondition.ENDED)) {
#             throw new IllegalStateException("game ended");
#         }
#         if (players[currentPlayerIndex] != player) {
#             throw new IllegalArgumentException("not the current player");
#         }
#         if (board.getPlayerAt(colIndex, rowIndex) != null) {
#             throw new IllegalArgumentException("board position is taken");
#         }
#         board.updateBoard(colIndex, rowIndex, player);
#         final Move newMove = new Move(colIndex, rowIndex, player);
#         currentPlayerIndex = (currentPlayerIndex + 1) % players.length;
#         if (getGameStatus().equals(GameCondition.ENDED)) {
#             scoreTracker.reportGameResult(players[0], players[1], board.getWinner());
#         }
#     }
#
#     public GameCondition getGameStatus() {
#         Optional<Player> winner = board.getWinner();
#         if (winner.isPresent()) { return GameCondition.ENDED; }
#         return board.isFull() ? GameCondition.ENDED : GameCondition.IN_PROGRESS;
#     }
#
#     public Player getCurrentPlayer() { return players[currentPlayerIndex]; }
#     public ScoreTracker getScoreTracker() { return scoreTracker; }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Board</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e63946; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Board {
#     private final Player[][] grid = new Player[3][3];
#
#     public void updateBoard(int colIndex, int rowIndex, Player player) {
#         if (grid[colIndex][rowIndex] == null) {
#             grid[colIndex][rowIndex] = player;
#         }
#     }
#
#     public Optional<Player> getWinner() {
#         // Check rows
#         for (int i = 0; i < grid.length; i++) {
#             Player first = grid[i][0];
#             if (first != null && Arrays.stream(grid[i]).allMatch(p -> p == first)) {
#                 return Optional.of(first);
#             }
#         }
#         // Check columns
#         for (int j = 0; j < grid[0].length; j++) {
#             final Player first = grid[0][j];
#             int finalJ = j;
#             if (first != null && Arrays.stream(grid).allMatch(row -> row[finalJ] == first)) {
#                 return Optional.of(first);
#             }
#         }
#         // Check main diagonal
#         Player topLeft = grid[0][0];
#         if (topLeft != null
#                 && IntStream.range(0, grid.length).allMatch(i -> grid[i][i] == topLeft)) {
#             return Optional.of(topLeft);
#         }
#         // Check anti-diagonal
#         Player topRight = grid[0][grid[0].length - 1];
#         if (topRight != null
#                 && IntStream.range(0, grid.length)
#                         .allMatch(i -> grid[i][grid[0].length - 1 - i] == topRight)) {
#             return Optional.of(topRight);
#         }
#         return Optional.empty();
#     }
#
#     public boolean isFull() {
#         return Arrays.stream(grid).flatMap(Arrays::stream).noneMatch(Objects::isNull);
#     }
#
#     public void reset() {
#         for (Player[] players : grid) { Arrays.fill(players, null); }
#     }
#
#     public Player getPlayerAt(int colIndex, int rowIndex) {
#         return grid[colIndex][rowIndex];
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Player</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e63946; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Player {
#     private final String name;
#     private final char symbol;
#
#     public Player(String name, char symbol) {
#         this.name = name;
#         this.symbol = symbol;
#     }
#
#     public String getName() { return name; }
#     public char getSymbol() { return symbol; }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">ScoreTracker</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e63946; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# class ScoreTracker {
#     private HashMap<Player, Integer> playerRatings = new HashMap<>();
#
#     public void reportGameResult(Player player1, Player player2,
#                                   Optional<Player> winningPlayer) {
#         if (winningPlayer.isPresent()) {
#             Player winner = winningPlayer.get();
#             Player loser = player1 == winner ? player2 : player1;
#             playerRatings.putIfAbsent(winner, 0);
#             playerRatings.put(winner, playerRatings.get(winner) + 1);
#             playerRatings.putIfAbsent(loser, 0);
#             playerRatings.put(loser, playerRatings.get(loser) - 1);
#         }
#     }
#
#     public Map<Player, Integer> getTopPlayers() {
#         return playerRatings.entrySet().stream()
#                 .sorted(Map.Entry.comparingByValue(Comparator.reverseOrder()))
#                 .map(Map.Entry::getKey)
#                 .collect(Collectors.toMap(
#                         player -> player, player -> playerRatings.get(player)));
#     }
#
#     public int getRank(Player player) {
#         List<Player> sortedPlayers = playerRatings.entrySet().stream()
#                 .sorted(Map.Entry.comparingByValue(Comparator.reverseOrder()))
#                 .map(Map.Entry::getKey)
#                 .collect(Collectors.toList());
#         return sortedPlayers.indexOf(player) + 1;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #e63946; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(230,57,70,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Deep Dive Topic</span>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(230,57,70,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e63946;">Implement undo functionality</span>
# </div>

# %% [markdown]
# Let’s implement undo functionality using the **Memento Pattern**.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e63946; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e63946;">Step 1: Track move history</span>
# </div>

# %% [markdown]
# Every time a player makes a move, we store that move so it can be undone later. The Move class captures rowIndex, colIndex, and the player.

# %% [markdown]
# ![Figure 8: Move class (deep dive)](assets/image-10-8-VOHWWKQC.svg)

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e63946; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e63946;">Step 2: Store Moves with a Stack</span>
# </div>

# %% [markdown]
# Since moves occur in LIFO order, we use a stack (`ArrayDeque<Move>`).

# %% [markdown]
# ![Figure 9: MoveHistory class](assets/image-10-9-ULAMN2MF.svg)

# %% [markdown]
# <div style="border-left: 4px solid #e63946; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# class MoveHistory {
#     private final ArrayDeque<Move> history = new ArrayDeque<>();
#
#     public void recordMove(Move move) { history.push(move); }
#     public Move undoMove() { return history.pop(); }
#     public void clearHistory() { history.clear(); }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e63946; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e63946;">Step 3: Reverse the Board State</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e63946; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# // Updated makeMove in Game class
# public void makeMove(int colIndex, int rowIndex, Player player) {
#     if (getGameStatus().equals(GameCondition.ENDED)) {
#         throw new IllegalStateException("game ended");
#     }
#     if (players[currentPlayerIndex] != player) {
#         throw new IllegalArgumentException("not the current player");
#     }
#     if (board.getPlayerAt(colIndex, rowIndex) != null) {
#         throw new IllegalArgumentException("board position is taken");
#     }
#     board.updateBoard(colIndex, rowIndex, player);
#     final Move newMove = new Move(colIndex, rowIndex, player);
#     moveHistory.recordMove(newMove);
#     currentPlayerIndex = (currentPlayerIndex + 1) % players.length;
#     if (getGameStatus().equals(GameCondition.ENDED)) {
#         scoreTracker.reportGameResult(players[0], players[1], board.getWinner());
#     }
# }
#
# public void undoMove() {
#     if (getGameStatus().equals(GameCondition.ENDED)) {
#         throw new IllegalStateException("game ended and winner already reported");
#     }
#     final Move lastMove = moveHistory.undoMove();
#     if (currentPlayerIndex == 0) {
#         currentPlayerIndex = players.length - 1;
#     } else {
#         currentPlayerIndex--;
#     }
#     board.updateBoard(lastMove.getColIndex(), lastMove.getRowIndex(), null);
# }
# ```
#
# </div>

# %% [markdown]
# This is the essence of the **Memento Pattern**:

# %% [markdown]
# * **Memento** (Move): Stores the state of a single move.
#
# * **Caretaker** (MoveHistory): Maintains a stack of Move objects.
#
# * **Originator** (Game): Creates and restores from Move objects.

# %% [markdown]
# ![Figure 10: Undo functionality using the Memento Pattern](assets/image-10-10-4HHBD2NJ.svg)

# %% [markdown]
# <div style="border-left: 5px solid #e63946; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(230,57,70,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Wrap Up</span>
# </div>

# %% [markdown]
# In this chapter, we designed the Tic-Tac-Toe game. A key takeaway is the importance of modularity and clear separation of concerns. Each component — Board, Game, Player, and ScoreTracker — focuses on a specific responsibility.

# %% [markdown]
# In the deep dive section, we explored the Memento Pattern for undo functionality, enabling players to revert their moves while maintaining game state integrity.

# %% [markdown]
# Congratulations on getting this far! Now give yourself a pat on the back. Good job!
