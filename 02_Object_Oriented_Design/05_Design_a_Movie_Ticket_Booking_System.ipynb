# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon { font-size: 22px !important; line-height: 1.8 !important; }
# .jp-RenderedHTMLCommon h1 { font-size: 2.2em !important; }
# .jp-RenderedHTMLCommon h2 {
#   font-size: 1.7em !important;
#   border-left: 5px solid #e07a5f !important;
#   padding: 10px 0 10px 18px !important;
#   margin-top: 40px !important;
#   margin-bottom: 16px !important;
#   background: linear-gradient(90deg, rgba(224,122,95,0.08) 0%, transparent 60%) !important;
#   border-radius: 4px !important;
# }
# .jp-RenderedHTMLCommon h3 {
#   font-size: 1.35em !important;
#   border-bottom: 2px solid rgba(224,122,95,0.3) !important;
#   padding-bottom: 8px !important;
#   margin-top: 30px !important;
#   margin-bottom: 12px !important;
#   color: #e07a5f !important;
# }
# .jp-RenderedHTMLCommon h4 {
#   font-size: 1.15em !important;
#   font-style: italic !important;
#   color: #e07a5f !important;
#   margin-top: 22px !important;
# }
# </style>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #3d1308 0%, #6b3020 50%, #e07a5f 100%); padding: 40px 45px; border-radius: 16px; margin-bottom: 30px; border: 1px solid rgba(42,157,143,0.15); max-width: 95%; overflow: hidden; box-sizing: border-box;">
#   <div style="font-size: 15px; font-weight: 600; letter-spacing: 3px; text-transform: uppercase; color: #e07a5f; margin-bottom: 8px;">Chapter 05</div>
#   <div style="font-size: 36px; font-weight: 800; color: #ffffff; margin-bottom: 16px; line-height: 1.2;">Design a Movie Ticket Booking System</div>
#   <div style="width: 60px; height: 4px; background: linear-gradient(90deg, #e07a5f, rgba(42,157,143,0.5)); border-radius: 2px; margin-bottom: 18px;"></div>
#   <div style="font-size: 17px; color: #b0bec5; line-height: 1.6;">Object-Oriented Design Interview Question</div>
#   <div style="margin-top: 20px; font-size: 13px; color: #546e7a;">Source: ByteByteGo — Object-Oriented Design Interview</div>
# </div>

# %% [markdown]
# In this chapter, we'll walk through the design of a Movie Ticket Booking System. It's used to assess your ability to model real-world systems and apply object-oriented principles to create a well-structured solution. The goal is to carefully define the classes that represent key entities in a movie booking system, such as rooms, screenings, and movies. We'll aim to build a clear and functional structure that captures the essential interactions between these components, making the system intuitive and scalable.

# %% [markdown]
# Let's move on to gathering the specific requirements through a simulated interview scenario.

# %% [markdown]
# ![Figure 1: Movie Theater](assets/image-5-1-T2BO4U27.svg)

# %% [markdown]
# <div style="border-left: 5px solid #e07a5f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(224,122,95,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Requirements Gathering</span>
# </div>

# %% [markdown]
# Here is an example of a typical prompt an interviewer might give:

# %% [markdown]
# > “Imagine you’re trying to book tickets for a blockbuster movie on a busy weekend. You log into the booking system, browse through the available showtimes, select your preferred seats, and proceed to book them. Within moments, your tickets are confirmed, and you receive a digital ticket. Behind the scenes, the system is efficiently managing seat availability, tracking screenings, and calculating ticket costs. Now, let’s design a movie ticket booking system that handles all of this seamlessly.”

# %% [markdown]
# To refine the system’s scope, the candidate might ask the following questions:

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Requirements clarification</span>
# </div>

# %% [markdown]
# Here is an example of how a conversation between a candidate and an interviewer might unfold:

# %% [markdown]
# <div style="border: 1px solid rgba(224,122,95,0.3); border-radius: 8px; margin: 28px 0; overflow: hidden; font-family: system-ui, -apple-system, sans-serif;">
#   <div style="background: rgba(224,122,95,0.08); padding: 10px 20px; border-bottom: 1px solid rgba(224,122,95,0.3); display: flex; align-items: center; gap: 8px;">
#     <span style="font-size: 1.1em;">&#128483;</span>
#     <span style="font-size: 0.85em; font-weight: 700; color: #e07a5f; text-transform: uppercase; letter-spacing: 1.5px;">Interview Transcript</span>
#   </div>
#   <div style="padding: 24px 20px 24px 28px; position: relative;">
#     <div style="position: absolute; left: 38px; top: 24px; bottom: 24px; width: 2px; background: rgba(224,122,95,0.3);"></div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e07a5f; border: 3px solid transparent; box-shadow: 0 0 0 2px #e07a5f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e07a5f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e07a5f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Does the system support finding and booking tickets across different cinemas and rooms?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, users can search for available tickets across multiple cinemas, each containing multiple rooms.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e07a5f; border: 3px solid transparent; box-shadow: 0 0 0 2px #e07a5f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e07a5f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e07a5f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Does the system allow scheduling multiple screenings of the same movie across different rooms and times?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, each movie can have different screenings scheduled across various rooms and times in the same cinema or different cinemas.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e07a5f; border: 3px solid transparent; box-shadow: 0 0 0 2px #e07a5f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e07a5f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e07a5f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Does the system support different pricing tiers for seats within the same screening?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, each seat can have its pricing strategy, such as normal, premium, or VIP, affecting the ticket price.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e07a5f; border: 3px solid transparent; box-shadow: 0 0 0 2px #e07a5f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e07a5f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e07a5f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Can a user book multiple tickets in a single order, and how does the system calculate the total cost?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Yes, users can combine multiple tickets into one order for a specific screening. The system calculates the total cost by summing the prices of all selected seats based on their rate classes.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e07a5f; border: 3px solid transparent; box-shadow: 0 0 0 2px #e07a5f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e07a5f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e07a5f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">Does the system need to handle payment processing as part of the booking process?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">For this design, we can ignore payment processing and focus on browsing, scheduling, seat selection, and booking tickets.</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #e07a5f; border: 3px solid transparent; box-shadow: 0 0 0 2px #e07a5f; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #e07a5f; font-size: 0.95em;">Candidate</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #e07a5f; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Candidate</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">What happens when a user books a ticket for a specific seat?</div>
#       </div>
#     </div>
#     <div style="display: flex; gap: 18px; align-items: flex-start; margin-bottom: 22px; position: relative;">
#       <div style="width: 22px; height: 22px; border-radius: 50%; background: #8899aa; border: 3px solid transparent; box-shadow: 0 0 0 2px #8899aa; flex-shrink: 0; margin-top: 2px; z-index: 1;"></div>
#       <div style="flex: 1;">
#         <div style="display: flex; align-items: baseline; gap: 10px; margin-bottom: 4px;">
#           <span style="font-weight: 700; color: #8899aa; font-size: 0.95em;">Interviewer</span>
#           <span style="font-size: 0.75em; font-weight: 600; color: white; background: #8899aa; padding: 1px 8px; border-radius: 10px; text-transform: uppercase; letter-spacing: 0.5px;">Interviewer</span>
#         </div>
#         <div style="color: inherit; line-height: 1.7; font-size: 0.95em;">The system should create a ticket with the screening, seat, and price based on the seat’s pricing strategy, then add it to the screening’s ticket list, marking the seat as booked.</div>
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Requirements</span>
# </div>

# %% [markdown]
# Based on the questions and answers, the following functional requirements can be identified:

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e07a5f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e07a5f;">Movie and screening management</span>
# </div>

# %% [markdown]
# * Each cinema is located at a specific location and contains multiple rooms.
#
# * Movies can have multiple screenings scheduled across different rooms, cinemas, and time slots.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e07a5f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e07a5f;">Seat management and pricing</span>
# </div>

# %% [markdown]
# * Each room has a grid of seats available for booking.
#
# * Seats within a room can have varying pricing strategies (e.g., normal, premium, VIP) that affect ticket prices.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e07a5f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e07a5f;">User search and book flow</span>
# </div>

# %% [markdown]
# * Users can find and book available tickets.
#
# * A ticket represents a specific seat to watch a movie in a room at a particular time.
#
# * A user can book multiple tickets within the same order.
#
# * The total cost for an order is computed by summing the prices of all selected seats, based on their pricing tiers.

# %% [markdown]
# Below are the non-functional requirements:

# %% [markdown]
# * Fast searches for screenings for a smooth user experience.
#
# * Basic error handling should prevent booking conflicts, such as double-booking the same seat.

# %% [markdown]
# With these requirements in hand, the next step is to identify the core objects that will form the backbone of our system.

# %% [markdown]
# <div style="border-left: 5px solid #e07a5f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(224,122,95,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Identify Core Objects</span>
# </div>

# %% [markdown]
# To build a modular and maintainable system, we’ll define objects that represent distinct entities with clear responsibilities. Here are the core objects:

# %% [markdown]
# * **Movie**: Represents a specific movie shown in cinemas, capturing its essential details like title and duration.
#
# * **Cinema**: Models a physical location where movies are screened, containing multiple rooms.
#
# * **Room**: Defines a screening space within a cinema, tied to a unique layout of seats.
#
# * **Layout**: Organizes the seating arrangement in a room as a grid, managing seat positions.
#
# * **Seat**: Represents an individual seat in a room linked to a pricing strategy.
#
# * **Screening**: Combines a movie, a room, and a time slot to define when and where a movie is shown.
#
# * **Ticket**: Captures a customer’s choice of a specific seat for a screening, including its price.
#
# * **Order**: Groups multiple tickets purchased together into a single transaction, tracking the total cost.

# %% [markdown]
# **Design choice**: We separate Movie from Screening to distinguish fixed movie data from dynamic screening schedules, improving reusability and clarity.

# %% [markdown]
# **Design choice**: Separating Room from Layout allows rooms to share or customize seating arrangements, enhancing flexibility.

# %% [markdown]
# **Alternative approach**: We could merge Room and Layout into one class, but this limits flexibility if rooms need varied layouts. Another option is adding a Customer class, but since the focus is on booking mechanics, we prioritize ticket-related entities.

# %% [markdown]
# *Interview Tip: When presenting objects in an interview, explain why you chose them and how they meet the requirements. Mention alternatives (e.g., combining classes) to show you’ve considered different options and their trade-offs.*

# %% [markdown]
# <div style="border-left: 5px solid #e07a5f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(224,122,95,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Design Class Diagram</span>
# </div>

# %% [markdown]
# Now that we know the core objects and their roles, the next step is to create classes and methods to build the movie ticket booking system.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Movie</span>
# </div>

# %% [markdown]
# The Movie class captures essential details about a specific movie in the system. It focuses on static information, title, genre, and duration, data that remains constant across all screenings of that film.

# %% [markdown]
# ![Figure 2: Movie class](assets/image-5-2-7RMXNYUD.svg)

# %% [markdown]
# **Design choice**: We designed the Movie class to be a standalone entity, independent of cinema-specific or scheduling contexts. This isolation allows the same Movie to be reused across multiple cinemas and screenings without data duplication.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Seat</span>
# </div>

# %% [markdown]
# The Seat class holds key details about an individual seat, including its unique number. It uses the strategy pattern, implemented through the PricingStrategy interface with concrete classes like NormalRate, PremiumRate, and VIPRate, to manage price calculation flexibly.

# %% [markdown]
# The strategy pattern benefits the system in two key ways:

# %% [markdown]
# * It promotes extensibility, making it easy to add new rate classes.
#
# * It reduces code redundancy by using a single Seat class for all pricing variations.

# %% [markdown]
# ![Figure 3: Seat and PricingStrategy Design](assets/image-5-3-XHLJZHNM.svg)

# %% [markdown]
# **Alternate approach**: We could embed pricing logic directly in Seat, but this reduces flexibility if pricing rules change. The strategy pattern, while more complex, supports future extensions.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Layout</span>
# </div>

# %% [markdown]
# The Layout class acts as a bridge between individual seats and cinema rooms. It organizes seats into a grid structure defined by rows and columns. It uses a nested map (`Map<Integer, Map<Integer, Seat>>`) for efficient seat lookup, where the outer map’s key is the row number, the inner map’s key is the column number within that row, and the value is the Seat object at that position (row → column → seat).

# %% [markdown]
# It also maintains an index (`Map<String, Seat>`) to locate seats by their seat numbers quickly.

# %% [markdown]
# ![Figure 4: Layout class](assets/image-5-4-R6L2XMI7.svg)

# %% [markdown]
# **Alternative approach**: In Layout, we use a nested map for seat arrangement instead of a 2D array. This allows dynamic row creation with `computeIfAbsent` and supports variable row sizes. A 2D array could work for fixed-size rooms but lacks flexibility for irregular layouts or dynamic additions.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Cinema and Room</span>
# </div>

# %% [markdown]
# The Cinema and Room classes structure the cinema system by leveraging the seat and layout framework. A Cinema contains multiple Room instances, exemplifying composition. Each Room includes a Layout to define its seat arrangement.

# %% [markdown]
# ![Figure 5: Cinema and Room classes](assets/image-5-5-K53ZDUD7.svg)

# %% [markdown]
# **Design choice**: We structured the Cinema and Room with a compositional relationship to simulate a real-world cinema with multiple screening rooms.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Screening</span>
# </div>

# %% [markdown]
# With the cinema structure in place, the Screening class defines a specific showing of a movie in a particular room at a scheduled time. It combines a Movie, a Room, and time details into a single entity.

# %% [markdown]
# ![Figure 6: Screening class](assets/image-5-6-CXRGCTUI.svg)

# %% [markdown]
# **Design choice**: The Screening class centralizes scheduling details, making it easier to manage showtimes across cinemas.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Ticket</span>
# </div>

# %% [markdown]
# The Ticket class represents a purchased seat for a specific Screening, combining a Screening and a Seat. It includes a price attribute, capturing the seat’s cost at the time of purchase.

# %% [markdown]
# ![Figure 7: Ticket class](assets/image-5-7-EYFNG4OL.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Order</span>
# </div>

# %% [markdown]
# The Order class groups multiple tickets into a single transaction, capturing all tickets purchased together at a specific time. It tracks the order’s timestamp and provides the total cost of the tickets.

# %% [markdown]
# ![Figure 8: Order class](assets/image-5-8-KHRJNUWD.svg)

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">ScreeningManager</span>
# </div>

# %% [markdown]
# The ScreeningManager class manages key operations, such as searching for screenings of specific movies, identifying available seats, and storing purchased tickets.

# %% [markdown]
# ![Figure 9: ScreeningManager class](assets/image-5-9-VBALQNZV.svg)

# %% [markdown]
# **Design choice**: The ScreeningManager class serves as a central coordinator for screening and ticket-related operations. An alternative could be to embed these operations in the Cinema class, but this would couple static cinema attributes with scheduling/booking logic, reducing modularity.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">MovieBookingSystem</span>
# </div>

# %% [markdown]
# The MovieBookingSystem class is the final piece that brings all components together. It acts as a facade, streamlining user interactions by delegating tasks to underlying classes like ScreeningManager, Movie, and Cinema.

# %% [markdown]
# ![Figure 10: MovieBookingSystem class](assets/image-5-10-ONU5T6QU.svg)

# %% [markdown]
# **Alternate approach**: We designed the MovieBookingSystem class as a facade to provide a simplified interface. An alternative could be to allow client code to directly interact with classes like ScreeningManager or Cinema. However, this would increase coupling between clients and internal components.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Complete Class Diagram</span>
# </div>

# %% [markdown]
# Below is the class diagram of our movie ticket booking system.

# %% [markdown]
# ![Figure 11: Class Diagram of Movie Ticket Booking System](assets/image-5-11-YBN3QBZZ.svg)

# %% [markdown]
# <div style="border-left: 5px solid #e07a5f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(224,122,95,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Code - Movie Ticket Booking System</span>
# </div>

# %% [markdown]
# In this section, we’ll implement the core functionalities of the movie ticket booking system.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Movie</span>
# </div>

# %% [markdown]
# The Movie class represents the static details of a film. The class is designed to be immutable.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Movie {
#     private final String title;
#     private final String genre;
#     private final int durationInMinutes;
#
#     public Movie(String title, String genre, int durationInMinutes) {
#         this.title = title;
#         this.genre = genre;
#         this.durationInMinutes = durationInMinutes;
#     }
#
#     public Duration getDuration() {
#         return Duration.ofMinutes(durationInMinutes);
#     }
#
#     // getter methods are omitted for brevity
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Cinema</span>
# </div>

# %% [markdown]
# The Cinema class represents a cinema with attributes such as its name, location, and collection of Room objects.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Cinema {
#     private final String name;
#     private final String location;
#     private final List<Room> rooms;
#
#     public Cinema(String name, String location) {
#         this.name = name;
#         this.location = location;
#         this.rooms = new ArrayList<>();
#     }
#
#     public void addRoom(Room room) {
#         rooms.add(room);
#     }
#     // getter and setter methods are omitted for brevity
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Room</span>
# </div>

# %% [markdown]
# The Room class represents a theater room within a cinema.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Room {
#     private final String roomNumber;
#     private final Layout layout;
#
#     public Room(String roomNumber, Layout layout) {
#         this.roomNumber = roomNumber;
#         this.layout = layout;
#     }
#     // getter and setter methods are omitted for brevity
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Layout</span>
# </div>

# %% [markdown]
# The Layout class defines the seating arrangement of a cinema room using a nested map for position-based access and a separate map for seat number lookup.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Layout {
#     private final int rows;
#     private final int columns;
#     private final Map<String, Seat> seatsByNumber;
#     private final Map<Integer, Map<Integer, Seat>> seatsByPosition;
#
#     public Layout(int rows, int columns) {
#         this.rows = rows;
#         this.columns = columns;
#         this.seatsByNumber = new HashMap<>();
#         this.seatsByPosition = new HashMap<>();
#         initializeLayout();
#     }
#
#     private void initializeLayout() {
#         for (int i = 0; i < rows; i++) {
#             for (int j = 0; j < columns; j++) {
#                 String seatNumber = i + "-" + j;
#                 addSeat(seatNumber, i, j, new Seat(seatNumber, null));
#             }
#         }
#     }
#
#     public void addSeat(String seatNumber, int row, int column, Seat seat) {
#         seatsByNumber.put(seatNumber, seat);
#         seatsByPosition.computeIfAbsent(row, k -> new HashMap<>()).put(column, seat);
#     }
#
#     public Seat getSeatByNumber(String seatNumber) {
#         return seatsByNumber.get(seatNumber);
#     }
#
#     public Seat getSeatByPosition(int row, int column) {
#         Map<Integer, Seat> rowSeats = seatsByPosition.get(row);
#         return (rowSeats != null) ? rowSeats.get(column) : null;
#     }
#
#     public List<Seat> getAllSeats() {
#         return List.copyOf(seatsByNumber.values());
#     }
# }
# ```
#
# </div>

# %% [markdown]
# * **addSeat**: employs `computeIfAbsent` to dynamically create rows in the nested map as needed.
#
# * **getSeatByNumber**: retrieves a seat based on its unique string identifier.
#
# * **getSeatByPosition**: accesses a seat using its row and column coordinates.
#
# * **getAllSeats**: returns an unmodifiable list of all seats.

# %% [markdown]
# **Implementation choice**: We used a nested `Map<Integer, Map<Integer, Seat>>` for the seat grid and a `Map<String, Seat>` for seat number lookup, providing efficient O(1) access. An alternative could be a 2D array (`Seat[][]`), which is simpler for fixed-size layouts but lacks flexibility for irregular layouts.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Seat</span>
# </div>

# %% [markdown]
# The Seat class represents an individual seat with its unique seatNumber and associated PricingStrategy.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Seat {
#     private final String seatNumber;
#     private PricingStrategy pricingStrategy;
#
#     public Seat(String seatNumber, PricingStrategy pricingStrategy) {
#         this.seatNumber = seatNumber;
#         this.pricingStrategy = pricingStrategy;
#     }
#     // getter and setter methods are omitted for brevity
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">PricingStrategy</span>
# </div>

# %% [markdown]
# The PricingStrategy interface establishes a contract for pricing. Concrete classes like NormalRate, PremiumRate, and VIPRate encapsulate fixed price values for different seat types.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public interface PricingStrategy {
#     BigDecimal getPrice();
# }
#
# public class NormalRate implements PricingStrategy {
#     private final BigDecimal price;
#
#     public NormalRate(BigDecimal price) {
#         this.price = price;
#     }
#
#     @Override
#     public BigDecimal getPrice() {
#         return price;
#     }
# }
#
# public class PremiumRate implements PricingStrategy {
#     private final BigDecimal price;
#
#     public PremiumRate(BigDecimal price) {
#         this.price = price;
#     }
#
#     @Override
#     public BigDecimal getPrice() {
#         return price;
#     }
# }
#
# public class VIPRate implements PricingStrategy {
#     private final BigDecimal price;
#
#     public VIPRate(BigDecimal price) {
#         this.price = price;
#     }
#
#     @Override
#     public BigDecimal getPrice() {
#         return price;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Screening</span>
# </div>

# %% [markdown]
# The Screening class combines a Movie with a specific room, time, and duration.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Screening {
#     private final Movie movie;
#     private final Room room;
#     private final LocalDateTime startTime;
#     private final LocalDateTime endTime;
#
#     public Screening(Movie movie, Room room, LocalDateTime startTime, LocalDateTime endTime) {
#         this.movie = movie;
#         this.room = room;
#         this.startTime = startTime;
#         this.endTime = endTime;
#     }
#
#     public Duration getDuration() {
#         return Duration.between(startTime, endTime);
#     }
#     // getter and setter methods are omitted for brevity
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Ticket</span>
# </div>

# %% [markdown]
# The Ticket class connects a Screening with a specific Seat and assigns a price at the time of booking.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Ticket {
#     private final Screening screening;
#     private final Seat seat;
#     private final BigDecimal price;
#
#     public Ticket(Screening screening, Seat seat, BigDecimal price) {
#         this.screening = screening;
#         this.seat = seat;
#         this.price = price;
#     }
#     // getter and setter methods are omitted for brevity
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Order</span>
# </div>

# %% [markdown]
# The Order class represents a single transaction, encapsulating a collection of Ticket objects purchased together.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class Order {
#     private final List<Ticket> tickets;
#     private final LocalDateTime orderDate;
#
#     public Order(LocalDateTime orderDate) {
#         this.tickets = new ArrayList<>();
#         this.orderDate = orderDate;
#     }
#
#     public void addTicket(Ticket ticket) {
#         tickets.add(ticket);
#     }
#
#     public BigDecimal calculateTotalPrice() {
#         return tickets.stream()
#                 .map(Ticket::getPrice)
#                 .reduce(BigDecimal.ZERO, BigDecimal::add);
#     }
#     // getter and setter methods are omitted for brevity
# }
# ```
#
# </div>

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">ScreeningManager</span>
# </div>

# %% [markdown]
# The ScreeningManager class serves as a centralized manager for showtimes and tickets.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class ScreeningManager {
#     private final Map<Movie, List<Screening>> screeningsByMovie;
#     private final Map<Screening, List<Ticket>> ticketsByScreening;
#
#     public ScreeningManager() {
#         this.screeningsByMovie = new HashMap<>();
#         this.ticketsByScreening = new HashMap<>();
#     }
#
#     public void addScreening(Movie movie, Screening screening) {
#         screeningsByMovie.computeIfAbsent(movie, k -> new ArrayList<>()).add(screening);
#     }
#
#     public List<Screening> getScreeningsForMovie(Movie movie) {
#         return screeningsByMovie.getOrDefault(movie, new ArrayList<>());
#     }
#
#     public void addTicket(Screening screening, Ticket ticket) {
#         ticketsByScreening.computeIfAbsent(screening, k -> new ArrayList<>()).add(ticket);
#     }
#
#     public List<Ticket> getTicketsForScreening(Screening screening) {
#         return ticketsByScreening.getOrDefault(screening, new ArrayList<>());
#     }
#
#     public List<Seat> getAvailableSeats(Screening screening) {
#         List<Seat> allSeats = screening.getRoom().getLayout().getAllSeats();
#         List<Ticket> bookedTickets = getTicketsForScreening(screening);
#
#         List<Seat> availableSeats = new ArrayList<>(allSeats);
#         for (Ticket ticket : bookedTickets) {
#             availableSeats.remove(ticket.getSeat());
#         }
#         return availableSeats;
#     }
# }
# ```
#
# </div>

# %% [markdown]
# **Implementation choice**: We used `Map<Movie, List<Screening>>` and `Map<Screening, List<Ticket>>` for O(1) lookup. An alternative with `List<Screening>` and manual filtering would result in O(n) search times.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">MovieBookingSystem</span>
# </div>

# %% [markdown]
# The MovieBookingSystem class serves as a facade, providing a simplified interface for managing all operations.

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class MovieBookingSystem {
#     private final List<Movie> movies;
#     private final List<Cinema> cinemas;
#     private final ScreeningManager screeningManager;
#
#     public MovieBookingSystem() {
#         this.movies = new ArrayList<>();
#         this.cinemas = new ArrayList<>();
#         this.screeningManager = new ScreeningManager();
#     }
#
#     public void addMovie(Movie movie) {
#         movies.add(movie);
#     }
#
#     public void addCinema(Cinema cinema) {
#         cinemas.add(cinema);
#     }
#
#     public void addScreening(Movie movie, Screening screening) {
#         screeningManager.addScreening(movie, screening);
#     }
#
#     public void bookTicket(Screening screening, Seat seat) {
#         BigDecimal price = seat.getPricingStrategy().getPrice();
#         Ticket ticket = new Ticket(screening, seat, price);
#         screeningManager.addTicket(screening, ticket);
#     }
#
#     public List<Screening> getScreeningsForMovie(Movie movie) {
#         return screeningManager.getScreeningsForMovie(movie);
#     }
#
#     public List<Seat> getAvailableSeats(Screening screening) {
#         return screeningManager.getAvailableSeats(screening);
#     }
#
#     public int getTicketCount(Screening screening) {
#         return screeningManager.getTicketsForScreening(screening).size();
#     }
#
#     public List<Ticket> getTicketsForScreening(Screening screening) {
#         return screeningManager.getTicketsForScreening(screening);
#     }
# }
# ```
#
# </div>

# %% [markdown]
# The **bookTicket** method dynamically calculates the price using the associated seat’s PricingStrategy, creates a new Ticket, and stores it in the ScreeningManager.

# %% [markdown]
# <div style="border-left: 5px solid #e07a5f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(224,122,95,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Deep Dive Topics</span>
# </div>

# %% [markdown]
# Now that the basic design is complete, the interviewer might ask you to enhance the system’s functionality or accommodate more complex use cases.

# %% [markdown]
# <div style="border-bottom: 2px solid rgba(224,122,95,0.3); padding-bottom: 8px; margin: 28px 0 14px 0;">
#   <span style="font-size: 1.3em; font-weight: 600; color: #e07a5f;">Handling concurrent bookings</span>
# </div>

# %% [markdown]
# In OOD interviews, concurrency is often discussed for systems like movie ticket booking, where multiple users interact simultaneously.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e07a5f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e07a5f;">Problem: Race condition</span>
# </div>

# %% [markdown]
# A race condition occurs when two users attempt to book the same seat at the same time, potentially leading to both receiving confirmation, causing a double-booking.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e07a5f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e07a5f;">Solution: Pessimistic and Optimistic locking</span>
# </div>

# %% [markdown]
# To prevent race conditions, we can use locking mechanisms. There are two common approaches:

# %% [markdown]
# **Pessimistic Locking**: Acquires an exclusive lock on a seat at the start of a user’s booking process. The lock is held throughout the transaction. A timeout mechanism (e.g., 30 seconds) automatically releases the lock if the transaction remains incomplete. Well-suited for high-contention scenarios.

# %% [markdown]
# **Optimistic Locking**: Avoids locking seats during the booking process, instead verifying seat availability at the transaction’s final stage. Lightweight and efficient in low-contention scenarios, but frequent conflicts can degrade user experience.

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e07a5f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e07a5f;">Implementation: Pessimistic locking</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# public class SeatLockManager {
#     private final Map<String, SeatLock> lockedSeats = new ConcurrentHashMap<>();
#     private final Duration lockDuration;
#
#     public SeatLockManager(Duration lockDuration) {
#         this.lockDuration = lockDuration;
#     }
#
#     public synchronized boolean lockSeat(Screening screening, Seat seat, String userId) {
#         String lockKey = generateLockKey(screening, seat);
#         cleanupLockIfExpired(lockKey);
#         if (isLocked(screening, seat)) {
#             return false;
#         }
#         SeatLock lock = new SeatLock(userId, LocalDateTime.now().plus(lockDuration));
#         lockedSeats.put(lockKey, lock);
#         return true;
#     }
#
#     public synchronized boolean isLocked(Screening screening, Seat seat) {
#         String lockKey = generateLockKey(screening, seat);
#         cleanupLockIfExpired(lockKey);
#         return lockedSeats.containsKey(lockKey);
#     }
#
#     private void cleanupLockIfExpired(String lockKey) {
#         SeatLock lock = lockedSeats.get(lockKey);
#         if (lock != null && lock.isExpired()) {
#             lockedSeats.remove(lockKey);
#         }
#     }
#
#     private String generateLockKey(Screening screening, Seat seat) {
#         return screening.getId() + "-" + seat.getSeatNumber();
#     }
#
#     private static class SeatLock {
#         private final String userId;
#         private final LocalDateTime expirationTime;
#
#         public SeatLock(String userId, LocalDateTime expirationTime) {
#             this.userId = userId;
#             this.expirationTime = expirationTime;
#         }
#
#         public boolean isExpired() {
#             return LocalDateTime.now().isAfter(expirationTime);
#         }
#     }
# }
# ```
#
# </div>

# %% [markdown]
# <div style="margin: 22px 0 10px 0; border-left: 3px solid #e07a5f; padding-left: 10px;">
#   <span style="font-size: 1.15em; font-weight: 600; font-style: italic; color: #e07a5f;">Implementation: Optimistic locking</span>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #e07a5f; border-radius: 4px; overflow: hidden; margin: 15px 0;">
#
# ```java
# // Simplified optimistic locking in ScreeningManager
# public synchronized Ticket bookSeatOptimistically(Screening screening, Seat seat) {
#     if (isSeatBooked(screening, seat)) {
#         throw new IllegalStateException("Seat is already booked");
#     }
#
#     BigDecimal price = seat.getPricingStrategy().getPrice();
#     Ticket ticket = new Ticket(screening, seat, price);
#     ticketsByScreening.computeIfAbsent(screening, k -> new ArrayList<>()).add(ticket);
#     return ticket;
# }
#
# private boolean isSeatBooked(Screening screening, Seat seat) {
#     List<Ticket> tickets = getTicketsForScreening(screening);
#     return tickets.stream().anyMatch(ticket -> ticket.getSeat().equals(seat));
# }
# ```
#
# </div>

# %% [markdown]
# *Interview Tip: Discussing concurrency shows your ability to handle advanced scenarios. Pessimistic locking is often preferred for popular screenings with high contention, while optimistic locking suits simpler cases with fewer conflicts.*

# %% [markdown]
# <div style="border-left: 5px solid #e07a5f; padding: 12px 0 12px 20px; margin: 35px 0 18px 0; background: linear-gradient(90deg, rgba(224,122,95,0.08) 0%, transparent 60%); border-radius: 4px;">
#   <span style="font-size: 1.6em; font-weight: 700;">Wrap Up</span>
# </div>

# %% [markdown]
# In this chapter, we gathered requirements for the Movie Ticket Booking System through a series of thoughtful questions and answers. We then identified the core objects involved, designed the class structure, and implemented the key components of the system.

# %% [markdown]
# A key takeaway from this design is the significance of modularity and adherence to the single responsibility principle. Each component, such as the Movie, ScreeningManager, Seat, and Order classes, handles a distinct responsibility, ensuring the system remains maintainable and adaptable for future enhancements.

# %% [markdown]
# Our design choices, such as separating Movie and Screening or using a strategy pattern for pricing, prioritize flexibility and scalability. An alternative, like merging Screening and Ticket, might simplify the model but could complicate individual seat management.

# %% [markdown]
# Congratulations on getting this far! Now give yourself a pat on the back. Good job!
